# %% [markdown]
# # Auditoría Drive — Carpeta de Rocío
#
# Escanea las carpetas de Rocío en Drive para encontrar sus resultados de entrenamiento
# y poder incluirlos en la tabla comparativa.
#
# No borra ni modifica nada — solo lista y lee metricas.json si existen.

# %%
from google.colab import drive
import os
if os.path.isdir('/content/drive') and os.listdir('/content/drive'):
    print('Drive ya montado.')
else:
    drive.mount('/content/drive')
    print('Drive montado.')
# Out:
# Drive ya montado.

# %%
# ── Buscar carpetas de Rocío en todas las rutas posibles ──────
from pathlib import Path
import json

DRIVE = '/content/drive/MyDrive'

def tamanyo(n):
    for u in ['B','KB','MB','GB']:
        if n < 1024: return f'{n:.0f}{u}'
        n /= 1024
    return f'{n:.1f}TB'

# Nombres de carpeta que puede usar Rocío
NOMBRES_POSIBLES = [
    'Rocio', 'Rocío', 'rocio', 'ROCIO',
    'E3_Rocio', 'E3_Rocío', 'E3-Rocio',
    'Rocio_E3', 'modelo_rocio', 'resultados_rocio',
]

# Directorios raíz donde buscar
RAICES = [
    f'{DRIVE}/Datos_E2_E3/E3',
    f'{DRIVE}/Datos_E2_E3',
    f'{DRIVE}',
]

encontradas = []

print('Buscando carpetas de Rocío...')
for raiz in RAICES:
    p = Path(raiz)
    if not p.exists(): continue
    try:
        for hijo in p.iterdir():
            if hijo.is_dir():
                nombre_lower = hijo.name.lower()
                if any(n.lower() in nombre_lower for n in NOMBRES_POSIBLES):
                    encontradas.append(hijo)
                    print(f'  [ENCONTRADA] {hijo}')
    except PermissionError:
        pass

if not encontradas:
    print('  No se encontró ninguna carpeta con nombre de Rocío.')
    print('  Comprueba si usa otro nombre — ejecuta la celda de abajo para listar todo E3/')
# Out:
# Buscando carpetas de Rocío...
#   [ENCONTRADA] /content/drive/MyDrive/Rocio

# %%
# ── Listar TODO lo que hay en Datos_E2_E3/E3/ ────────────────
# Ejecuta esto si la celda anterior no encontró nada

from pathlib import Path

DRIVE = '/content/drive/MyDrive'
e3 = Path(f'{DRIVE}/Datos_E2_E3/E3')

def tamanyo(n):
    for u in ['B','KB','MB','GB']:
        if n < 1024: return f'{n:.0f}{u}'
        n /= 1024
    return f'{n:.1f}TB'

if e3.exists():
    print(f'Contenido de {e3}:')
    for hijo in sorted(e3.iterdir()):
        if hijo.is_dir():
            try:
                n = len(list(hijo.iterdir()))
                # Intentar contar subcarpetas
                subcarpetas = [x for x in hijo.iterdir() if x.is_dir()]
                print(f'  📁 {hijo.name}/  ({n} elementos, {len(subcarpetas)} subcarpetas)')
                for sub in sorted(subcarpetas)[:5]:  # max 5 para no flood
                    try:
                        ns = len(list(sub.iterdir()))
                        print(f'       📁 {sub.name}/  ({ns} elementos)')
                    except: pass
            except: print(f'  📁 {hijo.name}/  [error]')
        else:
            print(f'  📄 {hijo.name}')
else:
    print(f'No existe: {e3}')
    print('Intentando listar MyDrive raíz...')
    for hijo in sorted(Path(DRIVE).iterdir()):
        print(f'  {"📁" if hijo.is_dir() else "📄"} {hijo.name}')
# Out:
# Contenido de /content/drive/MyDrive/Datos_E2_E3/E3:
#   📁 Raquel/  (5 elementos, 4 subcarpetas)
#        📁 modelos/  (11 elementos)
#        📁 notebooks/  (20 elementos)
#        📁 resultados/  (11 elementos)
#        📁 visualizaciones/  (1 elementos)
#   📁 checkpoints_pcn/  (56 elementos, 0 subcarpetas)
#   📁 checkpoints_pcn_v3/  (15 elementos, 0 subcarpetas)
#   📁 checkpoints_pcn_v4/  (1 elementos, 1 subcarpetas)
#        📁 pretrain/  (9 elementos)
#   📁 checkpoints_pcn_v8/  (1 elementos, 1 subcarpetas)
#        📁 finetune/  (8 elementos)
#   📁 checkpoints_pcn_v9/  (2 elementos, 2 subcarpetas)
#        📁 finetune/  (25 elementos)
#        📁 pretrain/  (9 elementos)
#   📁 checkpoints_topnet/  (3 elementos, 3 subcarpetas)
#        📁 finetune/  (17 elementos)
#        📁 finetune_congelado/  (19 elementos)
#        📁 pretrain/  (7 elementos)

# %%
# ── Escanear en detalle las carpetas de Rocío encontradas ─────
# Ajusta RUTAS_ROCIO si sabes dónde está su carpeta

from pathlib import Path
import json
from datetime import datetime

DRIVE = '/content/drive/MyDrive'

# ── AJUSTA ESTO si sabes la ruta exacta de Rocío ──────────────
RUTAS_ROCIO = [
    # Descomenta/añade la ruta correcta:
    # f'{DRIVE}/Datos_E2_E3/E3/Rocio',
    # f'{DRIVE}/Datos_E2_E3/E3/Rocío',
] + [str(p) for p in encontradas]  # usa las encontradas automáticamente

def tamanyo(n):
    for u in ['B','KB','MB','GB']:
        if n < 1024: return f'{n:.0f}{u}'
        n /= 1024
    return f'{n:.1f}TB'

def fecha(p):
    try: return datetime.fromtimestamp(p.stat().st_mtime).strftime('%Y-%m-%d')
    except: return '?'

resultados_rocio = []  # acumula metricas.json encontrados

for ruta_str in RUTAS_ROCIO:
    ruta = Path(ruta_str)
    if not ruta.exists():
        print(f'[NO EXISTE] {ruta}')
        continue

    print(f'\n{"="*60}')
    print(f'Carpeta: {ruta}')
    print('='*60)

    for hijo in sorted(ruta.rglob('*')):
        rel = hijo.relative_to(ruta)
        prof = len(rel.parts) - 1
        ind = '  ' * prof

        if hijo.is_dir():
            try: n = len(list(hijo.iterdir()))
            except: n = '?'
            print(f'{ind}📁 {hijo.name}/  ({n} elem)')
        elif hijo.suffix == '.pt':
            try: sz = tamanyo(hijo.stat().st_size)
            except: sz = '?'
            print(f'{ind}📦 {hijo.name}  {sz}  {fecha(hijo)}')
        elif hijo.name == 'metricas.json':
            try:
                m = json.loads(hijo.read_text())
                print(f'{ind}📊 metricas.json → version={m.get("version")}  '
                      f'CD={m.get("cd_l1")}  F={m.get("f_score")}  '
                      f'ep={m.get("best_epoch")}  test={m.get("n_test")}')
                resultados_rocio.append(m)
            except Exception as e:
                print(f'{ind}📊 metricas.json  [error: {e}]')
        elif hijo.suffix in ('.csv', '.txt', '.png', '.npy', '.ply', '.ipynb'):
            try: sz = tamanyo(hijo.stat().st_size)
            except: sz = '?'
            print(f'{ind}📄 {hijo.name}  {sz}')

print(f'\nTotal metricas.json encontrados: {len(resultados_rocio)}')
if not RUTAS_ROCIO:
    print('⚠️  No se encontraron rutas de Rocío. Ejecuta la Celda 2 primero o edita RUTAS_ROCIO manualmente.')
# Out:
# ============================================================
# Carpeta: /content/drive/MyDrive/Rocio
# ============================================================
# 📁 fantastik breaks/  (3 elem)
# 📁 objaverse/  (4 elem)
# 📁 scripts modelos/  (3 elem)
#   📁 pcn/  (7 elem)
#     📄 E3_PCN_mejorado_v3.ipynb  2MB
#     📄 E3_PCN_mejorado_v4.ipynb  2MB
#     📄 E3_PCN_mejorado_v5.ipynb  2MB
#     📄 E3_PCN_mejorado_v6.ipynb  2MB
#     📄 E3_PCN_mejorado_v7.ipynb  2MB
#     📄 E3_PCN_prueba_overfitting_1ejemplo.ipynb  782KB
#     📄 E3_PCN_v9_filtrado.ipynb  3MB
#   📁 pointtr/  (2 elem)
#     📄 E3_PoinTr_Objaverse_FB.ipynb  2MB
#     📄 E3_PoinTr_Objaverse_FB_v2.ipynb  42KB
#   📁 topnet/  (1 elem)
#     📄 E3_TopNet_v1.ipynb  3MB
# 📁 shapenet/  (1 elem)
#   📄 roturas_descartadas.csv  51KB
# 📄 visualizar_pares_roto_completo.ipynb  2MB
#
# Total metricas.json encontrados: 0

# %%
# ── Resumen para copiar a Claude ─────────────────────────────
# Escanea con profundidad controlada (sin rglob) — rápido en Drive

from datetime import datetime
import json
from pathlib import Path

DRIVE = '/content/drive/MyDrive'
BASE  = f'{DRIVE}/Datos_E2_E3'

def tamanyo(n):
    for u in ['B','KB','MB','GB']:
        if n < 1024: return f'{n:.0f}{u}'
        n /= 1024
    return f'{n:.1f}TB'

def listar_nivel(carpeta, profundidad=0, max_prof=3):
    """Lista un directorio sin recursión descontrolada."""
    lineas = []
    ind = '  ' * profundidad
    try:
        hijos = sorted(Path(carpeta).iterdir())
    except Exception as e:
        return [f'{ind}[error: {e}]']

    archivos = [h for h in hijos if h.is_file()]
    subdirs  = [h for h in hijos if h.is_dir()]

    # Agrupar archivos por extensión con tamaño total
    if archivos:
        por_ext = {}
        total_sz = 0
        for f in archivos:
            try: sz = f.stat().st_size
            except: sz = 0
            total_sz += sz
            ext = f.suffix.lower() or '(sin ext)'
            por_ext.setdefault(ext, []).append(f.name)
        ext_resumen = ', '.join(f'{len(v)}x{k}' for k,v in sorted(por_ext.items()))
        lineas.append(f'{ind}  📄 {len(archivos)} archivos [{ext_resumen}] — {tamanyo(total_sz)}')
        # Mostrar archivos individuales si parecen resultados
        for f in archivos:
            ext = f.suffix.lower()
            if ext in ('.json','.csv','.txt') or 'metrica' in f.name.lower() or 'result' in f.name.lower():
                try: sz = tamanyo(f.stat().st_size)
                except: sz = '?'
                # Si es JSON, intentar leer CD/F
                extra = ''
                if ext == '.json':
                    try:
                        d = json.loads(f.read_text())
                        if 'cd_l1' in d or 'f_score' in d:
                            extra = f'  → CD={d.get("cd_l1")}  F={d.get("f_score")}  ep={d.get("best_epoch")}'
                    except: pass
                lineas.append(f'{ind}    🔍 {f.name}  ({sz}){extra}')

    # Subcarpetas
    for d in subdirs:
        try: n = len(list(d.iterdir()))
        except: n = '?'
        lineas.append(f'{ind}  📁 {d.name}/  ({n} elementos)')
        if profundidad < max_prof - 1:
            lineas.extend(listar_nivel(d, profundidad + 1, max_prof))

    return lineas


lineas = []
lineas.append('=== AUDITORÍA DRIVE ROCÍO ===')
lineas.append(f'Fecha: {datetime.now().strftime("%Y-%m-%d %H:%M")}')

# 1. Listar E3/ un nivel para encontrar la carpeta de Rocío
lineas.append('')
lineas.append('--- CONTENIDO DE Datos_E2_E3/E3/ ---')
e3 = Path(f'{BASE}/E3')
carpetas_e3 = []
if e3.exists():
    try:
        for hijo in sorted(e3.iterdir()):
            if hijo.is_dir():
                try: n = len(list(hijo.iterdir()))
                except: n = '?'
                lineas.append(f'  📁 {hijo.name}/  ({n} elementos)')
                carpetas_e3.append(hijo)
            else:
                lineas.append(f'  📄 {hijo.name}')
    except Exception as ex:
        lineas.append(f'  [error: {ex}]')
else:
    lineas.append(f'  [NO EXISTE] {e3}')

# 2. Escanear en detalle todas las carpetas que NO sean "Raquel"
lineas.append('')
lineas.append('--- DETALLE CARPETAS (excluye Raquel) ---')
excluir = {'raquel'}
for carpeta in carpetas_e3:
    if carpeta.name.lower() in excluir:
        continue
    lineas.append(f'')
    lineas.append(f'  📂 {carpeta.name}/')
    lineas.extend(listar_nivel(carpeta, profundidad=1, max_prof=4))

# 3. También listar E3/Raquel brevemente (un nivel)
raquel = e3 / 'Raquel'
if raquel.exists():
    lineas.append('')
    lineas.append('--- E3/Raquel/ (referencia — un nivel) ---')
    try:
        for h in sorted(raquel.iterdir()):
            if h.is_dir():
                try: n = len(list(h.iterdir()))
                except: n = '?'
                lineas.append(f'  📁 {h.name}/  ({n} elementos)')
    except: pass

lineas.append('')
lineas.append('=== FIN AUDITORÍA ===')

txt = '\n'.join(lineas)
print(txt)
print()
print('↑ Copia todo el texto y pégalo en Claude.')
# Out:
# === AUDITORÍA DRIVE ROCÍO ===
# Fecha: 2026-08-27 18:49
#
# --- CONTENIDO DE Datos_E2_E3/E3/ ---
#   📁 Raquel/  (5 elementos)
#   📁 checkpoints_pcn/  (56 elementos)
#   📁 checkpoints_pcn_v3/  (15 elementos)
#   📁 checkpoints_pcn_v4/  (1 elementos)
#   📁 checkpoints_pcn_v8/  (1 elementos)
#   📁 checkpoints_pcn_v9/  (2 elementos)
#   📁 checkpoints_topnet/  (3 elementos)
#
# --- DETALLE CARPETAS (excluye Raquel) ---
#
#   📂 checkpoints_pcn/
#     📄 56 archivos [56x.pt] — 879MB
#
#   📂 checkpoints_pcn_v3/
#     📄 15 archivos [1x.json, 14x.pt] — 251MB
#       🔍 estado_entrenamiento.json  (12KB)
#
#   📂 checkpoints_pcn_v4/
#     📁 pretrain/  (9 elementos)
#       📄 9 archivos [1x.json, 8x.pt] — 157MB
#         🔍 estado_entrenamiento.json  (6KB)
#
#   📂 checkpoints_pcn_v8/
#     📁 finetune/  (8 elementos)
#       📄 8 archivos [1x.json, 7x.pt] — 141MB
#         🔍 estado_entrenamiento.json  (5KB)
#
#   📂 checkpoints_pcn_v9/
#     📁 finetune/  (25 elementos)
#       📄 25 archivos [1x.json, 24x.pt] — 408MB
#         🔍 estado_entrenamiento.json  (22KB)
#     📁 pretrain/  (9 elementos)
#       📄 9 archivos [1x.json, 8x.pt] — 157MB
#         🔍 estado_entrenamiento.json  (6KB)
#
#   📂 checkpoints_topnet/
#     📁 finetune/  (17 elementos)
#       📄 17 archivos [1x.json, 16x.pt] — 97MB
#         🔍 estado_entrenamiento.json  (15KB)
#     📁 finetune_congelado/  (19 elementos)
#       📄 19 archivos [1x.json, 18x.pt] — 99MB
#         🔍 estado_entrenamiento.json  (17KB)
#     📁 pretrain/  (7 elementos)
#       📄 7 archivos [1x.json, 6x.pt] — 43MB
#         🔍 estado_entrenamiento.json  (5KB)
#
# --- E3/Raquel/ (referencia — un nivel) ---
#   📁 modelos/  (11 elementos)
#   📁 notebooks/  (20 elementos)
#   📁 resultados/  (11 elementos)
#   📁 visualizaciones/  (1 elementos)
#
# === FIN AUDITORÍA ===
#
# ↑ Copia todo el texto y pégalo en Claude.

# %%
# Leer estado_entrenamiento.json de Rocío
import json
from pathlib import Path

DRIVE = '/content/drive/MyDrive'
BASE = f'{DRIVE}/Datos_E2_E3/E3'

ckpt_dirs = [
    'checkpoints_pcn', 'checkpoints_pcn_v3',
    'checkpoints_pcn_v4', 'checkpoints_pcn_v8',
    'checkpoints_pcn_v9', 'checkpoints_topnet',
]

for ckpt in ckpt_dirs:
    base = Path(f'{BASE}/{ckpt}')
    if not base.exists(): continue
    # Buscar estado_entrenamiento.json a un nivel de profundidad
    jsons = list(base.glob('estado_entrenamiento.json')) + \
            list(base.glob('*/estado_entrenamiento.json'))
    for jp in sorted(jsons):
        try:
            d = json.loads(jp.read_text())
            sub = jp.parent.name if jp.parent.name != ckpt else '(raíz)'
            print(f'\n[{ckpt}/{sub}]')
            # Mostrar todos los campos que parezcan métricas
            for k, v in d.items():
                print(f'  {k}: {v}')
        except Exception as e:
            print(f'[ERROR] {jp}: {e}')
# Out:
# [checkpoints_pcn_v3/(raíz)]
#   epoca: 300
#   historial_train: [0.18359889356947656, 0.15049904251276558, 0.14275153581775837, 0.13880239827419394, 0.13462221566865692, 0.13014570790440289, 0.12812767022136431, 0.12613681503641072, 0.12447387335905388, 0.12219179488384901, 0.12000748859857445, 0.11877829503657213, 0.11677979133022365, 0.11719204874625846, 0.11605350840002743, 0.11398422684687287, 0.11335878974910993, 0.11129331121693796, 0.11213172338346937, 0.1103177161803886, 0.1092251188941856, 0.10980675858792974, 0.10901652343237578, 0.10880488290715573, 0.10769663528719944, 0.10762424188763348, 0.10698831748606553, 0.10633418486634297, 0.10566974887207373, 0.10489920593464552, 0.10550824385970387, 0.10507560699288525, 0.10439654606491772, 0.10458038825152526, 0.10371474265607435, 0.10327181509181635, 0.10327170144266157, 0.10322484574211177, 0.10223455827182798, 0.10159949302228528, 0.10054178068886942, 0.09999497045776737, 0.09964601773379454, 0.10059835472658499, 0.09867769868961021, 0.09864723404396826, 0.09897130027190963, 0.09852909407953718, 0.09888515943911538, 0.09877901468703996, 0.09856280862395443, 0.09840831471912896, 0.09752223640680313, 0.09802392903548568, 0.09797870634651895, 0.09755662862044662, 0.09734359728311424, 0.09763656667808988, 0.09725406932741848, 0.10429948357058995, 0.10479273291221305, 0.10393081360788488, 0.10440400798818958, 0.10558415760300052, 0.10446122866957935, 0.10458946895243516, 0.1034312183732417, 0.10378960809156076, 0.10211966954060454, 0.10356841670043433, 0.10317555514734182, 0.10313833115705803, 0.1027058177252314, 0.10219826204563255, 0.10243471978760477, 0.1023590669258317, 0.10238914158362061, 0.10239804046812342, 0.10193168527599591, 0.10219241756556639, 0.10110756143260358, 0.10133772410118758, 0.10114833545773777, 0.10082080003930562, 0.10066246119008135, 0.10030756990856199, 0.10042536447742093, 0.0995523936268109, 0.10042758930974932, 0.10031191226261765, 0.10026652821853979, 0.09990607646863851, 0.09978151777342184, 0.09980840914285005, 0.0995471082738976, 0.09941812793710339, 0.09990178026370149, 0.09963700086323184, 0.09959594694091313, 0.09953707189702277, 0.09885485003243631, 0.10001638976495657, 0.09952835749779175, 0.09904559735041946, 0.09917424040943829, 0.09939856649334751, 0.09846482370326769, 0.09951123350591802, 0.09931626159753372, 0.09909868051311863, 0.09955395268860148, 0.0986964287820147, 0.09922943041840596, 0.09840591385293362, 0.09901346421953458, 0.09805620950994207, 0.09893503195759076, 0.09854867209249468, 0.09875433447200861, 0.12859729243748225, 0.12752682359805748, 0.1270394684441054, 0.1270935664426035, 0.1270944611794913, 0.1255719622791703, 0.12590614450511647, 0.12622158974409103, 0.12582585059884768, 0.12592434960959561, 0.1261124020414566, 0.12621195714420347, 0.12516250294535908, 0.12640200110513772, 0.12530012250836217, 0.12556314034693278, 0.1250005652433011, 0.12559290964211992, 0.12479940446010276, 0.12579874583144687, 0.12591013056573583, 0.12544084351454207, 0.12587471139519962, 0.12536010301824826, 0.1257161357954367, 0.125330993266248, 0.1252511886518393, 0.12581336120171333, 0.12554050937517366, 0.1252190952203167, 0.1251287053325283, 0.12537211302056242, 0.12556261224533194, 0.12605884304242349, 0.12570147082876804, 0.12527302541394733, 0.12476490804953362, 0.12521523693159445, 0.12475839980057817, 0.12450268731188419, 0.12464582419662333, 0.12506837909346197, 0.12421140630743396, 0.1241799537370454, 0.123734134902705, 0.12391486552669041, 0.12447272185514223, 0.1241029247419158, 0.12525661033925725, 0.12418580844775955, 0.12388341740440967, 0.12421726757910714, 0.1247005719524711, 0.12425574271091774, 0.12365076813235212, 0.1238671324368733, 0.12414077413615895, 0.12440433753515358, 0.12397546765964422, 0.12430795193163317, 0.1594715414207373, 0.15983064583878018, 0.15959413216185214, 0.15859547212942324, 0.15916958317827823, 0.15957925835652137, 0.1589586848198478, 0.15892856668180494, 0.1590802653956769, 0.1593233398092327, 0.15933081730088192, 0.1585680477654756,  ...
#   historial_val: [0.17752212658524513, 0.1718384101986885, 0.15480261482298374, 0.14978128857910633, 0.1388199906796217, 0.14365019463002682, 0.13565087877213955, 0.12424813117831945, 0.1278142360970378, 0.12411150895059109, 0.11317546386271715, 0.11083733569830656, 0.11615364905446768, 0.11167578026652336, 0.11322705447673798, 0.10662314854562283, 0.1007889499887824, 0.10786528792232275, 0.0979634840041399, 0.09675765410065651, 0.10070840828120708, 0.10001550987362862, 0.09270982909947634, 0.09254091791808605, 0.09478390961885452, 0.09439562819898129, 0.09238591603934765, 0.0889527015388012, 0.08932509552687407, 0.08963883481919765, 0.08860108442604542, 0.089937012642622, 0.08892422914505005, 0.08736632857471704, 0.08645086828619242, 0.0878770099952817, 0.08661413192749023, 0.08568909671157598, 0.08633243292570114, 0.08555456064641476, 0.08316144347190857, 0.08334574848413467, 0.08209753409028053, 0.08086389675736427, 0.08115192782133818, 0.08208135049790144, 0.08063503727316856, 0.07980917301028967, 0.07967363018542528, 0.08062199782580137, 0.08050424978137016, 0.08109737746417522, 0.0819826116785407, 0.08043377753347158, 0.07969297375530005, 0.07961121574044228, 0.07880140654742718, 0.07936683297157288, 0.08082528784871101, 0.08550985530018806, 0.0819782018661499, 0.08114850986748934, 0.07982961367815733, 0.08121986780315638, 0.07937013544142246, 0.08182599861174822, 0.08072727639228106, 0.07787533942610025, 0.07765973825007677, 0.07939306739717722, 0.07897351589053869, 0.07879599183797836, 0.07830567471683025, 0.07704611774533987, 0.07751497253775597, 0.07749158143997192, 0.07916620466858149, 0.07764601241797209, 0.07729765307158232, 0.07704227417707443, 0.07534243911504745, 0.07521635945886374, 0.07547080796211958, 0.07570305280387402, 0.0747238751500845, 0.07536256033927202, 0.07510777283459902, 0.07507876120507717, 0.07616045512259007, 0.07531003095209599, 0.07493714708834887, 0.0749903991818428, 0.0752976294606924, 0.07527263462543488, 0.07498349994421005, 0.07449792698025703, 0.07478461600840092, 0.07524819020181894, 0.07501195184886456, 0.07486615609377623, 0.07454726099967957, 0.07472753990441561, 0.07496271748095751, 0.07470549177378416, 0.07520223129540682, 0.07436207123100758, 0.07518766447901726, 0.07445787452161312, 0.07442712131887674, 0.07436844147741795, 0.07400313299149275, 0.07404300477355719, 0.0752817690372467, 0.07483436726033688, 0.07405084744095802, 0.07384187262505293, 0.07427464239299297, 0.07398582249879837, 0.0739168431609869, 0.07645329181104898, 0.0740409567952156, 0.07399347610771656, 0.0741556715220213, 0.07378951646387577, 0.07380684465169907, 0.07376626692712307, 0.0731638241559267, 0.07323480118066072, 0.0737635139375925, 0.07298689521849155, 0.07327203918248415, 0.07330027502030134, 0.07342283893376589, 0.07329006493091583, 0.07322980463504791, 0.07310986239463091, 0.07314500771462917, 0.07326807547360659, 0.0728706419467926, 0.07314938027411699, 0.0730086350813508, 0.07300738617777824, 0.07340111397206783, 0.07321787253022194, 0.07322601694613695, 0.07325582578778267, 0.07363440189510584, 0.07328855060040951, 0.073292869143188, 0.07310899440199137, 0.0731186755001545, 0.07332777604460716, 0.07310936227440834, 0.07290203962475061, 0.07307587191462517, 0.07298537064343691, 0.07321098819375038, 0.07282090000808239, 0.07303324434906244, 0.07269804086536169, 0.07283161766827106, 0.07277796790003777, 0.07286475878208876, 0.07285721972584724, 0.07246181648224592, 0.07270381785929203, 0.0724916523322463, 0.0725963581353426, 0.0724335378035903, 0.07277465611696243, 0.07280352525413036, 0.07264848239719868, 0.07240544073283672, 0.07276221457868814, 0.07240524981170893, 0.07270246651023626, 0.07236483320593834, 0.07246809359639883, 0.0726010175421834, 0.07260301988571882, 0.07245603203773499, 0.0722816875204444, 0.07232597284018993, 0.0725836856290698, 0.07253929879516363, 0.07268266100436449, 0.07286189403384924, 0.0722584156319499, 0.07216512132436037, 0.07251595240086317, 0.07280564960092306, 0.0 ...
#   mejor_val: 0.07150464970618486
#   epocas_sin_mejora: 0
#
# [checkpoints_pcn_v4/pretrain]
#   epoca: 150
#   historial_train: [0.17205303494746868, 0.1445010861525169, 0.1343475273022285, 0.12905530941027862, 0.12827275200532032, 0.12562940338483222, 0.12238495819843732, 0.12044324680016591, 0.11794423048312848, 0.11509332954883575, 0.11149316418629426, 0.11019883648707317, 0.10849235608027531, 0.10748757284421187, 0.10653893901751592, 0.10458224106293458, 0.10468568228758299, 0.10297349966489351, 0.10328878886424578, 0.1020360712821667, 0.0990804713505965, 0.09812563543136303, 0.09782900512218476, 0.09750121935055805, 0.09652363038980044, 0.0965547284254661, 0.09694017194784604, 0.09632878005504608, 0.09627846605502642, 0.10409030983081231, 0.10280004350038675, 0.10201826164355644, 0.1020632443519739, 0.10188470895473774, 0.10173381429452162, 0.1009418377509484, 0.10075232065640963, 0.10081175909592555, 0.10042188809468196, 0.10031133351417688, 0.09922687399845857, 0.09853146660786409, 0.09800350734820733, 0.09810714056858649, 0.09784628737431306, 0.09758554926285377, 0.09754290970472189, 0.09699407070875168, 0.09725374052157769, 0.09752564613635724, 0.09700936170724722, 0.09697871380127393, 0.09684843398057498, 0.09726440631426297, 0.09667191012547566, 0.09674919476875891, 0.09686932655481192, 0.09643687158823014, 0.09590220130406893, 0.12583733063477737, 0.12546488482218524, 0.12452145963907242, 0.12429729023805032, 0.1237164482474327, 0.12453874085958187, 0.12381094900461344, 0.12408715371902172, 0.12359886398682228, 0.12341700322352923, 0.12341687427117275, 0.12325146221197568, 0.12365101060042015, 0.12294362932443618, 0.12258268468655073, 0.12250191466166423, 0.12253774473300347, 0.1226447018293234, 0.12250681955080767, 0.12269073965457769, 0.12224386620980043, 0.12190581491360297, 0.12227669392640773, 0.12177347609629997, 0.12179402456833766, 0.12157755345106125, 0.12182405556623753, 0.12162537964490744, 0.12136376855465082, 0.12168709211624586, 0.15687834849724402, 0.1565816017297598, 0.15656050512423883, 0.15657491683959962, 0.15628910798292894, 0.15610655385714312, 0.1562753521479093, 0.15565922672931964, 0.15560705638848818, 0.15633697303441854, 0.1557488950399252, 0.1555760839810738, 0.15540666052928337, 0.1550902634859085, 0.15514421944434825, 0.15526253535197332, 0.15518692708932436, 0.1554563066134086, 0.1552992589198626, 0.15532896862580226, 0.1554613429766435, 0.15512991157861855, 0.15536128420096176, 0.1550235317303584, 0.1556995015877944, 0.1549690345158944, 0.1552984962096581, 0.1554613030873812, 0.1550689018689669, 0.15482962979720188, 0.22424808007020217, 0.2233446662242596, 0.22334946027168862, 0.22402572196263534, 0.22336300267623022, 0.22395790471480442, 0.22343459243957814, 0.2234056456730916, 0.22424680155057172, 0.22294452373798077, 0.22309331870996035, 0.22289158128775083, 0.2231987109551063, 0.2239007958999047, 0.22268418830174666, 0.22387837102779976, 0.22415995414440448, 0.22284315045063313, 0.22310212369148547, 0.22349084317684173, 0.22295659276155325, 0.2229073010958158, 0.22377079129219055, 0.22249286495722256, 0.22275423522178944, 0.22269417437223288, 0.2227265580342366, 0.22301776661322667, 0.22263210255366106, 0.22335921227931976, 0.22205182015895844]
#   historial_val: [0.1769264806061983, 0.16253554075956345, 0.1581521201878786, 0.13735548220574856, 0.13101358339190483, 0.1306314580142498, 0.12791090272367, 0.130628221668303, 0.12396105658262968, 0.12098227068781853, 0.10956488642841578, 0.10195305477827787, 0.102317382581532, 0.10277195367962122, 0.10453743394464254, 0.10040949564427137, 0.10217743553221226, 0.0973500283434987, 0.09006261918693781, 0.09049739129841328, 0.08585570845752954, 0.0844300240278244, 0.08379398286342621, 0.08392258640378714, 0.08319308049976826, 0.08396968711167574, 0.0822477899491787, 0.08084270264953375, 0.0815993444994092, 0.09660836216062307, 0.08753689751029015, 0.08221904933452606, 0.08005642145872116, 0.08021168690174818, 0.07903315126895905, 0.07879505399614573, 0.07989640440791845, 0.07636941224336624, 0.07795978989452124, 0.07771733775734901, 0.07492170203477144, 0.07463899068534374, 0.07426360715180635, 0.07394314091652632, 0.07381169684231281, 0.07391080632805824, 0.07499075680971146, 0.07427249290049076, 0.07542068790644407, 0.07388575654476881, 0.07388424128293991, 0.07408071123063564, 0.07355731353163719, 0.07321625482290983, 0.0740005373954773, 0.07343200873583555, 0.073222691193223, 0.07312337402254343, 0.07278493512421846, 0.07484686281532049, 0.07330209668725729, 0.07280979678034782, 0.07245805021375418, 0.07310120202600956, 0.07188051007688046, 0.07218644395470619, 0.07221982069313526, 0.07183429133147001, 0.07175856363028288, 0.07178294658660889, 0.0715485354885459, 0.07189393322914839, 0.0711286161094904, 0.07122732978314161, 0.0710298977792263, 0.07108131423592567, 0.07115954998880625, 0.07129251211881638, 0.07080853078514338, 0.07092555612325668, 0.07099685445427895, 0.07079950347542763, 0.07093748729676008, 0.0708337239921093, 0.07056042179465294, 0.07088668458163738, 0.07071094587445259, 0.07100124750286341, 0.07091289013624191, 0.07067290786653757, 0.07040514424443245, 0.07045476511120796, 0.07083921693265438, 0.07028291374444962, 0.07008135691285133, 0.07025247439742088, 0.07035061065107584, 0.07035161554813385, 0.07024945225566626, 0.07024317234754562, 0.07009087223559618, 0.0702101681381464, 0.06995211448520422, 0.07012581825256348, 0.07034432701766491, 0.07006735261529684, 0.07004539202898741, 0.07022587303072214, 0.07021477166563272, 0.07009684387594461, 0.07021037302911282, 0.06996999867260456, 0.07000582106411457, 0.06979129277169704, 0.06989184394478798, 0.07024704571813345, 0.0701020322740078, 0.06996475346386433, 0.07001716829836369, 0.07024872303009033, 0.06991055607795715, 0.0700512770563364, 0.07001325301826, 0.06991111300885677, 0.06977290008217096, 0.06985985580831766, 0.07001114264130592, 0.06975427735596895, 0.06990836746990681, 0.0698786498978734, 0.0696173245087266, 0.06976824533194304, 0.06984212435781956, 0.0699447887018323, 0.06971822772175074, 0.06994772981852293, 0.06973424926400185, 0.06976926978677511, 0.06971807777881622, 0.06986788101494312, 0.06978850159794092, 0.06964954640716314, 0.06961515173316002, 0.06981792487204075, 0.06969607155770063, 0.0696849012747407, 0.06957388203591108, 0.06967515591531992, 0.06971978396177292, 0.06991111859679222]
#   mejor_val: 0.06957388203591108
#   epocas_sin_mejora: 3
#
# [checkpoints_pcn_v8/finetune]
#   epoca: 126
#   historial_train: [0.2034487302104632, 0.18900168190399805, 0.18021743992964426, 0.17144696166117987, 0.17006920029719672, 0.168778824309508, 0.16010105858246484, 0.1616209844748179, 0.15910607079664865, 0.20355302840471268, 0.20773238192001978, 0.20939251283804575, 0.20320637275775275, 0.2019330064455668, 0.2048848569393158, 0.1941890815893809, 0.20229076345761618, 0.19921491791804632, 0.19806786874930063, 0.19446898251771927, 0.19049380968014398, 0.19071498016516367, 0.19194422413905463, 0.19007340321938196, 0.27661528686682385, 0.27798828730980557, 0.2786734998226166, 0.28125395874182385, 0.2876913050810496, 0.2786555190881093, 0.27250909556945163, 0.2681453377008438, 0.26738149921099347, 0.2746944800019264, 0.2722378969192505, 0.2653005321820577, 0.2809644788503647, 0.265445480744044, 0.26790354152520496, 0.2689926028251648, 0.26712073385715485, 0.25954866657654446, 0.26354782780011493, 0.26761426279942196, 0.25991672774155933, 0.2553082803885142, 0.2594420239329338, 0.2568513850371043, 0.25243397305409115, 0.2578482727209727, 0.25888949632644653, 0.2539619704087575, 0.2569677606225014, 0.24860118329524994, 0.24641378968954086, 0.2501256714264552, 0.24796785414218903, 0.25237702081600827, 0.25523721675078076, 0.25903142740329105, 0.24831456939379373, 0.24758456399043402, 0.25302092730998993, 0.25912530968586606, 0.2659876694281896, 0.25907576580842334, 0.25421516348918277, 0.24391951660315195, 0.24114491790533066, 0.25001491109530133, 0.24734813968340555, 0.2457816724975904, 0.24122650176286697, 0.242002102235953, 0.24306085954109827, 0.24237180004517236, 0.23498045653104782, 0.24519447485605875, 0.23950719088315964, 0.2467886060476303, 0.24155084788799286, 0.23742347210645676, 0.23857917139927545, 0.23714765657981238, 0.24090977013111115, 0.2352949654062589, 0.23806655903657278, 0.23965907593568167, 0.24007943520943323, 0.23594075441360474, 0.24035646518071493, 0.23644710083802542, 0.23736298580964407, 0.22837876031796137, 0.2339322343468666, 0.23073123147090277, 0.22655536979436874, 0.2349623739719391, 0.23492288341124853, 0.24309875319401422, 0.2260890007019043, 0.23031744609276453, 0.22851522515217462, 0.22694642841815948, 0.22402885059515634, 0.22362690170605978, 0.22587702671686807, 0.22240491956472397, 0.22539673497279486, 0.23092839866876602, 0.22038673361142477, 0.22527104864517847, 0.21903032312790552, 0.22104926904042563, 0.22413823753595352, 0.22542176395654678, 0.22487572332223257, 0.22149777660767236, 0.22550289581219354, 0.2218166763583819, 0.22369099408388138, 0.2224212015668551, 0.22238442798455557, 0.21912958224614462, 0.22584033012390137, 0.22399819393952689]
#   historial_val: [0.13120977580547333, 0.14099106192588806, 0.13910478353500366, 0.12576472759246826, 0.12399135529994965, 0.12419967353343964, 0.12933269143104553, 0.13031640648841858, 0.13043613731861115, 0.12833788990974426, 0.13275913894176483, 0.13690698146820068, 0.14058077335357666, 0.1294337511062622, 0.13023364543914795, 0.14315439760684967, 0.1489216536283493, 0.1350761353969574, 0.1270512491464615, 0.12921370565891266, 0.13580529391765594, 0.12780603766441345, 0.13249340653419495, 0.13484741747379303, 0.13380621373653412, 0.14350315928459167, 0.14535684883594513, 0.1486993432044983, 0.13411833345890045, 0.1402892768383026, 0.1419631689786911, 0.1543656885623932, 0.15668225288391113, 0.15027102828025818, 0.142818883061409, 0.14393164217472076, 0.14441269636154175, 0.13993597030639648, 0.1482330560684204, 0.1447756141424179, 0.14610517024993896, 0.13209207355976105, 0.13697707653045654, 0.14255759119987488, 0.136463463306427, 0.15143099427223206, 0.13719691336154938, 0.1338566541671753, 0.13951881229877472, 0.13870954513549805, 0.14119702577590942, 0.1420145332813263, 0.14424340426921844, 0.13984915614128113, 0.13329538702964783, 0.13519331812858582, 0.14362888038158417, 0.13461020588874817, 0.1466861367225647, 0.1367044448852539, 0.137189581990242, 0.13705112040042877, 0.13442747294902802, 0.13831418752670288, 0.13980144262313843, 0.13850651681423187, 0.13257701694965363, 0.14714348316192627, 0.1382467895746231, 0.13681739568710327, 0.133726567029953, 0.1356739103794098, 0.13358844816684723, 0.1356661319732666, 0.1371145248413086, 0.13116112351417542, 0.13935089111328125, 0.1305096298456192, 0.13398146629333496, 0.13320814073085785, 0.13957270979881287, 0.13380706310272217, 0.13633427023887634, 0.13743016123771667, 0.1359342336654663, 0.13147568702697754, 0.14247041940689087, 0.14085309207439423, 0.13569192588329315, 0.13735900819301605, 0.1361801028251648, 0.13743360340595245, 0.14045289158821106, 0.13453710079193115, 0.13747148215770721, 0.13915348052978516, 0.14314384758472443, 0.14282819628715515, 0.13341397047042847, 0.13643619418144226, 0.13836224377155304, 0.14024338126182556, 0.14248892664909363, 0.14138354361057281, 0.13628923892974854, 0.13690879940986633, 0.13505282998085022, 0.1345522403717041, 0.1389484703540802, 0.13847875595092773, 0.1344662457704544, 0.13454464077949524, 0.13438273966312408, 0.1361009180545807, 0.1348542422056198, 0.13372983038425446, 0.13812808692455292, 0.1360655128955841, 0.134363055229187, 0.13546420633792877, 0.1351385861635208, 0.1342056393623352, 0.13435816764831543, 0.1395232230424881, 0.14123594760894775, 0.1346420794725418]
#   mejor_val: 0.12399135529994965
#   epocas_sin_mejora: 121
#
# [checkpoints_pcn_v9/finetune]
#   epoca: 550
#   historial_train: [0.22865108152230582, 0.21067669242620468, 0.20125727355480194, 0.20071655760208765, 0.19984151422977448, 0.1967061087489128, 0.2003986512621244, 0.20046264678239822, 0.19438384970029196, 0.26230186223983765, 0.2642204314470291, 0.26103000342845917, 0.2561076954007149, 0.2598721037308375, 0.25999153157075244, 0.256730077167352, 0.2581103245417277, 0.2564581632614136, 0.2635268568992615, 0.2511899620294571, 0.2579245592157046, 0.24833187212546667, 0.24715166787306467, 0.25714324911435443, 0.3713012586037318, 0.38229016462961835, 0.38043149809042615, 0.37500931322574615, 0.3896498630444209, 0.3823094516992569, 0.37951397399107617, 0.3825099567572276, 0.3916686524947484, 0.3684612413247426, 0.3679255892833074, 0.3827596455812454, 0.3629817912975947, 0.3728769024213155, 0.3739507496356964, 0.37290770808855694, 0.3584725906451543, 0.3776656538248062, 0.3773782749970754, 0.3536387433608373, 0.35287363827228546, 0.35056980947653454, 0.3635650376478831, 0.3504626303911209, 0.34418925642967224, 0.35579123596350354, 0.34849784274895984, 0.35118845105171204, 0.3480762044588725, 0.33622462054093677, 0.3422415753205617, 0.3495529691378276, 0.3430715352296829, 0.35079923768838245, 0.35626106957594555, 0.34615330398082733, 0.34900803367296857, 0.3427436749140422, 0.3380441665649414, 0.32927054663499195, 0.3352243701616923, 0.34207314252853394, 0.34323414663473767, 0.3450481394926707, 0.35100382566452026, 0.35857346653938293, 0.33654358983039856, 0.347050944964091, 0.3371790647506714, 0.33719487984975177, 0.3374768793582916, 0.33748018741607666, 0.3306427250305812, 0.3431929349899292, 0.3384738067785899, 0.3210279792547226, 0.3335724224646886, 0.3239504148562749, 0.33569622536500293, 0.33026788135369617, 0.3250968009233475, 0.32822300493717194, 0.325169970591863, 0.31335822741190594, 0.3147192746400833, 0.3250502347946167, 0.3090933958689372, 0.32736994822820026, 0.32611455023288727, 0.30739373962084454, 0.31657811999320984, 0.3247580329577128, 0.32192106048266095, 0.3177117009957631, 0.3149939527114232, 0.30953695873419446, 0.3106053868929545, 0.30833434065183, 0.30559001863002777, 0.30660226941108704, 0.3186452041069667, 0.3072502215703328, 0.29953765869140625, 0.30747805039087933, 0.31155172487099964, 0.3033105830351512, 0.3029068261384964, 0.2975028157234192, 0.3043379286924998, 0.29804714024066925, 0.30462927122910816, 0.3034745405117671, 0.30104999740918476, 0.306453878680865, 0.30221640566984814, 0.30529145896434784, 0.29895778993765515, 0.2916207363208135, 0.3013114631175995, 0.2970171471436818, 0.2981302738189697, 0.29425988097985584, 0.29926903545856476, 0.2951062023639679, 0.3009423514207204, 0.2899380673964818, 0.2980802704890569, 0.2944229990243912, 0.3059580822785695, 0.29511132339636487, 0.290355587999026, 0.30231842895348865, 0.2847052216529846, 0.3067771593729655, 0.29548315207163495, 0.3006383230288823, 0.3007398098707199, 0.2929433484872182, 0.30221479137738544, 0.2890695184469223, 0.29558466374874115, 0.2995416174332301, 0.28939248124758404, 0.287819042801857, 0.2879891594250997, 0.2832925369342168, 0.2913161665201187, 0.2869091232617696, 0.29034223159154254, 0.28870778779188794, 0.2908260375261307, 0.28703267375628155, 0.28878820935885113, 0.28462837636470795, 0.287346492211024, 0.2892372210820516, 0.2914736320575078, 0.30155423780282337, 0.2865643898646037, 0.2974088788032532, 0.28771283229192096, 0.2907180239756902, 0.28748657802740735, 0.28669949372609455, 0.2918179805080096, 0.290835698445638, 0.2829725965857506, 0.2940019816160202, 0.28467567761739093, 0.2871541579564412, 0.29067542652289075, 0.28393280506134033, 0.2806963274876277, 0.2920067807038625, 0.2798837870359421, 0.2949229876200358, 0.2846188296874364, 0.2775874584913254, 0.28003652890523273, 0.2816319465637207, 0.29003887871901196, 0.28245006998380023, 0.2893691311279933, 0.287584421535333, 0.28426053126653034, 0.27699411412080127, 0.28835444649060565, 0.28563029567400616, 0.2789045174916585, 0.2837521682182948, 0.27676230669021606, 0.285 ...
#   historial_val: [0.1326766461133957, 0.1182825118303299, 0.1252206265926361, 0.1289195567369461, 0.12120683491230011, 0.12082266807556152, 0.11606147885322571, 0.11605371534824371, 0.13351351022720337, 0.1445622444152832, 0.18657642602920532, 0.11831292510032654, 0.13210205733776093, 0.18651145696640015, 0.14408279955387115, 0.1383749544620514, 0.15946432948112488, 0.15340496599674225, 0.1406823694705963, 0.1453566551208496, 0.14539995789527893, 0.15258847177028656, 0.13998830318450928, 0.11539963632822037, 0.13451868295669556, 0.12979352474212646, 0.13592904806137085, 0.14338862895965576, 0.14822910726070404, 0.16474351286888123, 0.15125037729740143, 0.13322630524635315, 0.11809732019901276, 0.12228529155254364, 0.1347092241048813, 0.15220028162002563, 0.13059687614440918, 0.14351806044578552, 0.12329088151454926, 0.1317688226699829, 0.14003922045230865, 0.15192176401615143, 0.12895679473876953, 0.11534367501735687, 0.12954369187355042, 0.15047341585159302, 0.1656738519668579, 0.1557246744632721, 0.1327151358127594, 0.11982983350753784, 0.11464308947324753, 0.11741530150175095, 0.1332588642835617, 0.14159922301769257, 0.12260319292545319, 0.12295494973659515, 0.13086406886577606, 0.14615410566329956, 0.13109731674194336, 0.12008108198642731, 0.12390780448913574, 0.12547191977500916, 0.1224474385380745, 0.10719909518957138, 0.10951118171215057, 0.11231212317943573, 0.12144097685813904, 0.11199188232421875, 0.1432279497385025, 0.11565768718719482, 0.13196730613708496, 0.11074903607368469, 0.10360942780971527, 0.10664243996143341, 0.1301458477973938, 0.1155320331454277, 0.11454570293426514, 0.11654768884181976, 0.11151252686977386, 0.11887536942958832, 0.11563888192176819, 0.12115630507469177, 0.12007489800453186, 0.11316358298063278, 0.10569779574871063, 0.11064592003822327, 0.12112551927566528, 0.1031000018119812, 0.10762432217597961, 0.11765532940626144, 0.10915717482566833, 0.11629030853509903, 0.11512592434883118, 0.11331987380981445, 0.10344171524047852, 0.10421572625637054, 0.10823474824428558, 0.11412057280540466, 0.11212355643510818, 0.11723969876766205, 0.1080775186419487, 0.1091625913977623, 0.11028800159692764, 0.10773652791976929, 0.1044350117444992, 0.10641641169786453, 0.11565279960632324, 0.11282023787498474, 0.10882176458835602, 0.10722502321004868, 0.10809668898582458, 0.10613074153661728, 0.10537615418434143, 0.10604266822338104, 0.11073437333106995, 0.10941386222839355, 0.10800352692604065, 0.09946905076503754, 0.10436472296714783, 0.11450669169425964, 0.10659819841384888, 0.10406842827796936, 0.10300993919372559, 0.10406021773815155, 0.10454516112804413, 0.1025862842798233, 0.1022089421749115, 0.10343904048204422, 0.10205855965614319, 0.10115863382816315, 0.1026231050491333, 0.10212500393390656, 0.10298866033554077, 0.10865280032157898, 0.10453832894563675, 0.10446542501449585, 0.10139937698841095, 0.10319221764802933, 0.10692493617534637, 0.09998434782028198, 0.09663252532482147, 0.09979162365198135, 0.10806925594806671, 0.10722696781158447, 0.10180523991584778, 0.10855694860219955, 0.10584638267755508, 0.10607986897230148, 0.10554538667201996, 0.10501116514205933, 0.10372962057590485, 0.09927491843700409, 0.09666461497545242, 0.099322110414505, 0.10019087046384811, 0.10067181289196014, 0.09795340150594711, 0.09972407668828964, 0.10706262290477753, 0.10176338255405426, 0.09839943796396255, 0.09887547791004181, 0.09728546440601349, 0.09954188764095306, 0.09818344563245773, 0.09956137090921402, 0.10454899072647095, 0.11016860604286194, 0.10452815890312195, 0.09746456146240234, 0.10044248402118683, 0.09857180714607239, 0.10344938933849335, 0.10684683918952942, 0.10352540016174316, 0.09671022742986679, 0.09503897279500961, 0.09627437591552734, 0.10105308890342712, 0.10483673214912415, 0.10498371720314026, 0.10053839534521103, 0.10301639139652252, 0.10427749156951904, 0.10766050219535828, 0.10122686624526978, 0.09618914127349854, 0.09396638721227646, 0.09601747989654541, 0.09626241028308868, 0.10015271604061127 ...
#   mejor_val: 0.08592794835567474
#   epocas_sin_mejora: 120
#
# [checkpoints_pcn_v9/pretrain]
#   epoca: 150
#   historial_train: [0.22436560392379762, 0.17346282303333282, 0.16156180799007416, 0.15742587447166442, 0.15558721125125885, 0.15144649595022203, 0.14716157019138337, 0.1433777093887329, 0.14210893213748932, 0.13664522171020507, 0.1339081570506096, 0.13303813338279724, 0.1304758831858635, 0.13087620437145234, 0.12942183017730713, 0.12812548726797104, 0.13259484842419625, 0.127015882730484, 0.12863281294703482, 0.12763753309845924, 0.12524740025401115, 0.12517091035842895, 0.12415203526616096, 0.1257728084921837, 0.12408676370978355, 0.12091690823435783, 0.12156880721449852, 0.12077866867184639, 0.12249878570437431, 0.1329120948910713, 0.13233171850442887, 0.13342417329549788, 0.12929024845361708, 0.1309688113629818, 0.13013388812541962, 0.12820008844137193, 0.1290610872209072, 0.12989777624607085, 0.1279915377497673, 0.1281289726495743, 0.1263098731637001, 0.12600380852818488, 0.12520078793168068, 0.1254316031932831, 0.12412371262907981, 0.1266294874250889, 0.1261111579835415, 0.12585509717464446, 0.12519206032156943, 0.12331664189696312, 0.12425662204623222, 0.12368314862251281, 0.12323096096515655, 0.12275477647781372, 0.1237957812845707, 0.12215194627642631, 0.1231742724776268, 0.12185397520661354, 0.1225381352007389, 0.16558163464069367, 0.16701850444078445, 0.1647253379225731, 0.16477346569299697, 0.16469224393367768, 0.16515208035707474, 0.16434926986694337, 0.16891096383333207, 0.1632113680243492, 0.1645558789372444, 0.16293065398931503, 0.16198337972164153, 0.1619054153561592, 0.16294467747211455, 0.1603464290499687, 0.15980847030878068, 0.16250420212745667, 0.1635589122772217, 0.16231732070446014, 0.16110658943653106, 0.15959400087594985, 0.15921429842710494, 0.1607753485441208, 0.1605238139629364, 0.15868898183107377, 0.1589063361287117, 0.15870798677206038, 0.1587158977985382, 0.16015525460243224, 0.16137683093547822, 0.2105716809630394, 0.2080027714371681, 0.20938007682561874, 0.20917026549577714, 0.21070717126131058, 0.21246976405382156, 0.2124108999967575, 0.2096267744898796, 0.2106490984559059, 0.2097845494747162, 0.20911056846380233, 0.2053816422820091, 0.2075418785214424, 0.20790470093488694, 0.20737799108028412, 0.20719706118106843, 0.20702022314071655, 0.2075117975473404, 0.20678114742040635, 0.20725215673446656, 0.20529329776763916, 0.20714362114667892, 0.20673379451036453, 0.20808578729629518, 0.20719388574361802, 0.2072652667760849, 0.20744195431470872, 0.20781982243061065, 0.20868225246667862, 0.20592590570449829, 0.3041836231946945, 0.30434533059597013, 0.3032295763492584, 0.30412236154079436, 0.30518888533115385, 0.30518130362033846, 0.30296191573143005, 0.30215263068675996, 0.3061528980731964, 0.3049032360315323, 0.3031563550233841, 0.3017024576663971, 0.303464475274086, 0.3022732138633728, 0.30321393609046937, 0.3052429884672165, 0.3013773649930954, 0.3078162133693695, 0.30284333527088164, 0.3024688929319382, 0.30553461611270905, 0.3055317342281342, 0.30153812766075133, 0.30073762536048887, 0.3053836852312088, 0.3011831521987915, 0.30484516322612765, 0.30138040482997897, 0.30590127408504486, 0.30312229692935944, 0.3020779401063919]
#   historial_val: [0.3097667023539543, 0.3112921416759491, 0.25510600954294205, 0.19557318091392517, 0.17188657820224762, 0.16006356477737427, 0.1564118191599846, 0.15662072598934174, 0.16671644151210785, 0.15681219100952148, 0.13831225410103798, 0.1537778377532959, 0.1343405805528164, 0.12772981077432632, 0.13905658200383186, 0.13137265294790268, 0.14325015246868134, 0.1434754654765129, 0.130956768989563, 0.12373476475477219, 0.12204325944185257, 0.12445749342441559, 0.1170259490609169, 0.12503289431333542, 0.11416488140821457, 0.11328070983290672, 0.11555517837405205, 0.11367345973849297, 0.11461465060710907, 0.11437297612428665, 0.12906108051538467, 0.13294677808880806, 0.12558979913592339, 0.12162692844867706, 0.126393161714077, 0.11860589310526848, 0.12282600998878479, 0.11862149834632874, 0.11284974589943886, 0.10864368826150894, 0.10539466142654419, 0.10660716146230698, 0.10449714213609695, 0.10395372658967972, 0.10367868468165398, 0.10326707363128662, 0.10490484163165092, 0.10193545743823051, 0.10114199668169022, 0.10372988507151604, 0.10120601952075958, 0.10084935277700424, 0.10258312150835991, 0.10231221467256546, 0.10202967375516891, 0.09871756285429001, 0.10289209336042404, 0.10091504827141762, 0.10316809266805649, 0.10290100052952766, 0.10605516657233238, 0.10229667648673058, 0.10102161392569542, 0.10082489997148514, 0.09931726008653641, 0.10201898589730263, 0.09750636294484138, 0.09925554692745209, 0.09880369901657104, 0.0971459224820137, 0.0970335491001606, 0.1005447544157505, 0.09764160960912704, 0.0954711101949215, 0.09710441157221794, 0.09482631832361221, 0.09553119540214539, 0.09537014365196228, 0.09541002660989761, 0.09395266324281693, 0.09319588169455528, 0.09299080818891525, 0.09240604564547539, 0.09316208213567734, 0.09163212776184082, 0.09318884462118149, 0.09205501526594162, 0.09211796149611473, 0.0933479480445385, 0.09433671459555626, 0.09308354556560516, 0.09546726942062378, 0.09367236867547035, 0.09218825027346611, 0.09222427755594254, 0.09152822196483612, 0.09330969676375389, 0.09302278608083725, 0.0921887680888176, 0.09240531176328659, 0.09186426177620888, 0.09110429510474205, 0.09189276397228241, 0.09136112406849861, 0.09313813969492912, 0.0920475386083126, 0.09156424552202225, 0.09210841357707977, 0.09093018248677254, 0.09037519618868828, 0.0909193903207779, 0.09126930311322212, 0.09089574217796326, 0.0907783955335617, 0.0908346101641655, 0.09046415239572525, 0.09178047627210617, 0.09048598259687424, 0.09109148383140564, 0.09061780944466591, 0.09028973057866096, 0.0914553850889206, 0.09108841791749, 0.09102927148342133, 0.09082746505737305, 0.09075414761900902, 0.09020789712667465, 0.089811522513628, 0.09022005647420883, 0.08973322808742523, 0.09009449928998947, 0.09055191650986671, 0.0900174118578434, 0.09070323035120964, 0.09052498266100883, 0.09101321548223495, 0.09164788201451302, 0.09029622003436089, 0.0899726152420044, 0.09038256853818893, 0.09086573868989944, 0.09019254893064499, 0.09015516936779022, 0.09052068740129471, 0.09035304933786392, 0.09039806947112083, 0.09019580110907555, 0.09005311876535416, 0.08981361612677574, 0.0894194208085537]
#   mejor_val: 0.0894194208085537
#   epocas_sin_mejora: 0
#
# [checkpoints_topnet/finetune]
#   epoca: 359
#   historial_train: [0.14081233739852905, 0.11973411838213603, 0.11269275844097137, 0.1075284518301487, 0.10831698775291443, 0.10335768262545268, 0.10179642091194789, 0.10237796107927959, 0.10566443701585133, 0.09919558713833491, 0.09941643352309863, 0.09763842696944873, 0.09567000220219295, 0.09562494233250618, 0.09616748119393985, 0.1008259691298008, 0.10217125092943509, 0.09910942489902179, 0.09592992564042409, 0.0956424946586291, 0.09511623779932658, 0.09428633004426956, 0.0930659423271815, 0.09487442175547282, 0.09888691455125809, 0.09638913224140803, 0.09279980262120564, 0.09455431376894315, 0.09271297479669253, 0.0927401880423228, 0.0940151959657669, 0.09614066779613495, 0.09353952233990033, 0.09010583534836769, 0.09277958050370216, 0.09088935206333797, 0.09146362791458766, 0.09157288695375125, 0.09171899904807408, 0.09419988840818405, 0.09561571851372719, 0.09360776096582413, 0.09137496476372083, 0.09092926854888599, 0.09271064524849255, 0.0931684064368407, 0.0956939955552419, 0.09217818081378937, 0.09465253601471584, 0.09160309781630833, 0.09119199216365814, 0.09105458110570908, 0.09202585493524869, 0.09048828730980556, 0.08846732104818027, 0.09337875122825305, 0.09255268673102061, 0.09465111295382182, 0.09139737735191981, 0.09341348583499591, 0.09188063566883405, 0.09002345303694408, 0.0892622930308183, 0.08942971751093864, 0.08901937305927277, 0.08914945274591446, 0.09288141379753749, 0.09064357976118724, 0.0884488175312678, 0.0865851491689682, 0.08706729114055634, 0.08650993679960568, 0.08554545293251674, 0.08631318310896556, 0.08726376667618752, 0.08524840449293454, 0.08660423755645752, 0.0857401005923748, 0.08404964332779248, 0.08609569817781448, 0.08617596452434857, 0.08555505548914273, 0.08936414370934169, 0.08694319302837054, 0.08428280552228291, 0.08339583252867062, 0.08241490398844083, 0.085343682517608, 0.08404312531153361, 0.08464173475901286, 0.08523857469360034, 0.08396172896027565, 0.08415728062391281, 0.08542540421088536, 0.08334829906622569, 0.08493295684456825, 0.08473226303855579, 0.08468596637248993, 0.08355085675915082, 0.08465120817224185, 0.08254008988539378, 0.08390458300709724, 0.08296044915914536, 0.0819738358259201, 0.08090066537261009, 0.08192438383897145, 0.08067747950553894, 0.08299601326386134, 0.08258364722132683, 0.08065823341409366, 0.0817529670894146, 0.08207210153341293, 0.08073564370473225, 0.08137365182240804, 0.08141094694534938, 0.08019641165932019, 0.08191210900743802, 0.07935673991839091, 0.08035665998856227, 0.08068704977631569, 0.08040238420168559, 0.08156461268663406, 0.0806075210372607, 0.0810740056137244, 0.08051018292705218, 0.07988463714718819, 0.08008882651726405, 0.08194900800784428, 0.08076366285483043, 0.07952357456088066, 0.07963199416796367, 0.08109751840432484, 0.08075689648588498, 0.0804273175696532, 0.0811892772714297, 0.08044655496875446, 0.07969106361269951, 0.07972103357315063, 0.08048215384284656, 0.07993094871441524, 0.08292657012740771, 0.07979747901360194, 0.08045506725708644, 0.08046179016431172, 0.08331939453879993, 0.08052773401141167, 0.08076635996500652, 0.08009991670648257, 0.07962566986680031, 0.07914861539999644, 0.07899853711326917, 0.08038110906879108, 0.08047131076455116, 0.08122116327285767, 0.079947330057621, 0.08058537046114604, 0.07833837469418843, 0.07970356568694115, 0.08080072700977325, 0.08062033851941426, 0.07969755058487256, 0.07751936962207158, 0.07890819509824117, 0.07830000792940457, 0.07938891649246216, 0.07919565960764885, 0.08127137149373691, 0.08001578226685524, 0.07822791362802188, 0.07974011699358623, 0.0797524352868398, 0.07912280907233556, 0.07936464622616768, 0.08098187545935313, 0.07999209066232045, 0.08151280010739963, 0.07987126087148984, 0.07826332623759906, 0.0788188564280669, 0.07937922328710556, 0.07973888516426086, 0.07902008543411891, 0.0794801873465379, 0.07839895288149516, 0.07851689929763477, 0.07944973434011142, 0.07873984426259995, 0.07926024993260701, 0.07872304817040761, 0.07826656103134155, 0.0774332669874 ...
#   historial_val: [0.10748061537742615, 0.10550498962402344, 0.11462731659412384, 0.10120312869548798, 0.10040455311536789, 0.1001419723033905, 0.10305464267730713, 0.09745457768440247, 0.09394095838069916, 0.09679678082466125, 0.09460152685642242, 0.09334780275821686, 0.09233462810516357, 0.0895526260137558, 0.09147553145885468, 0.09761518239974976, 0.0947144627571106, 0.08982741087675095, 0.09439368546009064, 0.09564392268657684, 0.0911993756890297, 0.08824114501476288, 0.08996839821338654, 0.08596992492675781, 0.09096375107765198, 0.08871245384216309, 0.10317599773406982, 0.08935800194740295, 0.09107393026351929, 0.08716432750225067, 0.09125620126724243, 0.08668462932109833, 0.0854501873254776, 0.0867302268743515, 0.09074977040290833, 0.09243971854448318, 0.08596252650022507, 0.09023134410381317, 0.09520827978849411, 0.09534873068332672, 0.08994083106517792, 0.08660459518432617, 0.08678580820560455, 0.09395448863506317, 0.08627971261739731, 0.09082116186618805, 0.08886410295963287, 0.08737632632255554, 0.09293490648269653, 0.09006115794181824, 0.09109708666801453, 0.08687140792608261, 0.08596158772706985, 0.0871407613158226, 0.09200809895992279, 0.0857427716255188, 0.08700080215930939, 0.09149930626153946, 0.08508478105068207, 0.09756691753864288, 0.08625313639640808, 0.08569289743900299, 0.08721772581338882, 0.08367657661437988, 0.08617550134658813, 0.08440545946359634, 0.08956904709339142, 0.08671343326568604, 0.08912283182144165, 0.08771463483572006, 0.08548211306333542, 0.08613046258687973, 0.08667716383934021, 0.08304782211780548, 0.08509223163127899, 0.084464430809021, 0.08400902897119522, 0.0822761282324791, 0.087339386343956, 0.08995291590690613, 0.08852212876081467, 0.08344827592372894, 0.08636676520109177, 0.08288118988275528, 0.0863872766494751, 0.08410633355379105, 0.08885076642036438, 0.08203089237213135, 0.08352495729923248, 0.08749255537986755, 0.08314673602581024, 0.0869947001338005, 0.08510294556617737, 0.08240209519863129, 0.09553560614585876, 0.08328629285097122, 0.08459484577178955, 0.08502921462059021, 0.08372823894023895, 0.08622732758522034, 0.08249069005250931, 0.08477060496807098, 0.08239257335662842, 0.08293762803077698, 0.08291934430599213, 0.08350398391485214, 0.08225813508033752, 0.08358168601989746, 0.08142915368080139, 0.0810709074139595, 0.08228591084480286, 0.08320215344429016, 0.08148249983787537, 0.08289147913455963, 0.08444082736968994, 0.08387057483196259, 0.08221041411161423, 0.08330846577882767, 0.08344808965921402, 0.08353482186794281, 0.08599503338336945, 0.08178858458995819, 0.08455201983451843, 0.08262753486633301, 0.08324609696865082, 0.08134441077709198, 0.08097248524427414, 0.08088429272174835, 0.08179415762424469, 0.08277368545532227, 0.08336810767650604, 0.08402986079454422, 0.08297000080347061, 0.08260174095630646, 0.08325956016778946, 0.08317667245864868, 0.08240219950675964, 0.08531610667705536, 0.0831952840089798, 0.08815675228834152, 0.08204355090856552, 0.08397740125656128, 0.0836687684059143, 0.08985776454210281, 0.08391449600458145, 0.0837889090180397, 0.08538010716438293, 0.08390848338603973, 0.08465752750635147, 0.08291666209697723, 0.08376903831958771, 0.08192647993564606, 0.08371224999427795, 0.08249668776988983, 0.08283570408821106, 0.08206138014793396, 0.0827803835272789, 0.08042362332344055, 0.08377278596162796, 0.07999497652053833, 0.08236387372016907, 0.08142168819904327, 0.08536534011363983, 0.08108043670654297, 0.08160929381847382, 0.08517181873321533, 0.08201251178979874, 0.08423379063606262, 0.08146054297685623, 0.08399974554777145, 0.08188439905643463, 0.08189094066619873, 0.08591620624065399, 0.08135512471199036, 0.08225752413272858, 0.08157318085432053, 0.08071814477443695, 0.08026720583438873, 0.08257590234279633, 0.0839349776506424, 0.08210746943950653, 0.08294397592544556, 0.08313406258821487, 0.08322826027870178, 0.08183051645755768, 0.08345316350460052, 0.0808136910200119, 0.08432849496603012, 0.08379186689853668, 0.08230061084032059, 0.087855391204 ...
#   mejor_val: 0.07947716116905212
#   epocas_sin_mejora: 121
#
# [checkpoints_topnet/finetune_congelado]
#   epoca: 405
#   historial_train: [0.1093849850197633, 0.10432619974017143, 0.10498381033539772, 0.10108500967423122, 0.09754570697744687, 0.09751436486840248, 0.0978131430844466, 0.09755693251887958, 0.09724200516939163, 0.0965864472091198, 0.09585915009180705, 0.09547814105947812, 0.09681655963261922, 0.09262112652262051, 0.0932284804681937, 0.09168051555752754, 0.09213386351863544, 0.09386561935146649, 0.09275426715612411, 0.09179795905947685, 0.09270911663770676, 0.09396287923057874, 0.09306576972206433, 0.09301902105410893, 0.09179935976862907, 0.09324801092346509, 0.09191285818815231, 0.0913994920750459, 0.09171961744626363, 0.09232497339447339, 0.09265536194046338, 0.09058817972739537, 0.09124191229542096, 0.09166078766187032, 0.0910278931260109, 0.09112181514501572, 0.09104394540190697, 0.09080974881847699, 0.09117869660258293, 0.09150544926524162, 0.09153492997090022, 0.09002677351236343, 0.0897176427145799, 0.08937763546903928, 0.08757102365295093, 0.08944259583950043, 0.08819328496853511, 0.08877498656511307, 0.0901831438144048, 0.09216737871368726, 0.09126385177175204, 0.089976171652476, 0.08904275173942248, 0.08981460332870483, 0.09042779852946599, 0.08877822756767273, 0.08986803516745567, 0.08852068831523259, 0.08924507225553195, 0.09051501750946045, 0.08891539151469867, 0.08836520587404569, 0.08879408240318298, 0.09080030148228009, 0.09017326310276985, 0.08940110231439273, 0.08920477082331975, 0.08763741205135982, 0.08682488277554512, 0.08691202849149704, 0.08816332866748174, 0.08708767096201579, 0.08965999508897464, 0.08624816685914993, 0.08753467475374539, 0.08717200035850207, 0.0865172694126765, 0.0863333431382974, 0.08710493768254916, 0.09054696559906006, 0.09148371840516727, 0.08892765765388806, 0.08734691391388576, 0.0867963470518589, 0.0879826694726944, 0.08585754161079724, 0.08764054998755455, 0.08751896272102992, 0.08603504796822865, 0.08799503743648529, 0.08607654025157292, 0.08470382293065389, 0.08664026483893394, 0.08497536679108937, 0.08683494478464127, 0.08622873201966286, 0.08720042556524277, 0.08649417509635289, 0.08560437336564064, 0.0854013202091058, 0.08492983380953471, 0.08543705567717552, 0.08521686121821404, 0.08592887843648593, 0.08520047242442767, 0.08671427766482036, 0.08368632569909096, 0.08469859262307484, 0.08505585665504138, 0.08555635313193004, 0.08163010825713475, 0.08327483261624972, 0.08349193508426349, 0.08496545627713203, 0.08348481232921283, 0.0835819033284982, 0.08458647007743518, 0.08370679368575414, 0.08395828555027644, 0.08546535174051921, 0.08391022061308225, 0.08309330170353253, 0.08243240416049957, 0.083387757341067, 0.08427091563741367, 0.08297066017985344, 0.08355796585480373, 0.08351352314154308, 0.08237602189183235, 0.0844038538634777, 0.08359600231051445, 0.08431468531489372, 0.08376345783472061, 0.08284152547518413, 0.08381155505776405, 0.08415117487311363, 0.08493704348802567, 0.08457066118717194, 0.08443946267167728, 0.08416092519958814, 0.08300766721367836, 0.08318330595890681, 0.08205132807294528, 0.08387184018890063, 0.08337294558684032, 0.08340321729580562, 0.08438664674758911, 0.08276563137769699, 0.08334022636214893, 0.08388784031073253, 0.0824947493771712, 0.0839627633492152, 0.08200671647985776, 0.08317321042219798, 0.08362945417563121, 0.08222442492842674, 0.08340410391489665, 0.08146124829848607, 0.08274589851498604, 0.08299645781517029, 0.0814642570912838, 0.08366220568617184, 0.0829131081700325, 0.08298102890451749, 0.08266577372948329, 0.08365510652462642, 0.08206712082028389, 0.08169170841574669, 0.08232147122422855, 0.08162179465095203, 0.08197518934806187, 0.0815628928442796, 0.08191445718208949, 0.08359818657239278, 0.08291460946202278, 0.08214306583007176, 0.08160526926318805, 0.08207520097494125, 0.08148694162567456, 0.08227469523747762, 0.08293156574169795, 0.08126090094447136, 0.08096304660042127, 0.08215926215052605, 0.08194735894600551, 0.0820118139187495, 0.08222586040695508, 0.0823678399125735, 0.08139837036530177, 0.08184502397974332, 0.08210098867615 ...
#   historial_val: [0.09877505153417587, 0.09584131836891174, 0.09422606229782104, 0.09691298007965088, 0.09303680807352066, 0.09708243608474731, 0.09284820407629013, 0.09073632955551147, 0.09331085532903671, 0.08981471508741379, 0.09148906916379929, 0.09021084010601044, 0.09335784614086151, 0.08895182609558105, 0.09275651723146439, 0.09051819145679474, 0.09318774938583374, 0.08846095204353333, 0.09082404524087906, 0.08761096000671387, 0.09192992746829987, 0.0877503752708435, 0.09281869232654572, 0.08745117485523224, 0.08711855113506317, 0.09070418775081635, 0.08878573030233383, 0.09033125638961792, 0.08495738357305527, 0.08837449550628662, 0.087418332695961, 0.08630487322807312, 0.08936067670583725, 0.08987386524677277, 0.08574710041284561, 0.08790990710258484, 0.08714272081851959, 0.08861088752746582, 0.08507892489433289, 0.08683501929044724, 0.08936255425214767, 0.08366622030735016, 0.09131459891796112, 0.08680061250925064, 0.08803728222846985, 0.0883769541978836, 0.08637739717960358, 0.08951161801815033, 0.0870000422000885, 0.09225165843963623, 0.0844750702381134, 0.09212169051170349, 0.08790111541748047, 0.08909818530082703, 0.08633773773908615, 0.09191630780696869, 0.08757874369621277, 0.08946205675601959, 0.09228230267763138, 0.08831263333559036, 0.08616426587104797, 0.08837723731994629, 0.09063245356082916, 0.08625570684671402, 0.09014907479286194, 0.08546486496925354, 0.08673170208930969, 0.08569037914276123, 0.08524638414382935, 0.08434590697288513, 0.08367478847503662, 0.0885966420173645, 0.08532839268445969, 0.0873207077383995, 0.08689779788255692, 0.08909302949905396, 0.08841320872306824, 0.08721864223480225, 0.08760519325733185, 0.08504320681095123, 0.08594164252281189, 0.08773727715015411, 0.08355231583118439, 0.09158078581094742, 0.08486562222242355, 0.08775530755519867, 0.08493439853191376, 0.0852918028831482, 0.08700381219387054, 0.0847158282995224, 0.08697329461574554, 0.08569864183664322, 0.08373597264289856, 0.08504244685173035, 0.08324867486953735, 0.08834205567836761, 0.08376022428274155, 0.08517605066299438, 0.08393068611621857, 0.08925282955169678, 0.08443789184093475, 0.08412353694438934, 0.08549858629703522, 0.08398124575614929, 0.08695165812969208, 0.08350535482168198, 0.08603431284427643, 0.0843082070350647, 0.08623012900352478, 0.0841665267944336, 0.08438457548618317, 0.0842948853969574, 0.08650785684585571, 0.08669514954090118, 0.0870191678404808, 0.08655565977096558, 0.0855807214975357, 0.0848061740398407, 0.08507487177848816, 0.08481374382972717, 0.08488602936267853, 0.08578822016716003, 0.08564618974924088, 0.08489412069320679, 0.08426693826913834, 0.08466702699661255, 0.08570504188537598, 0.08376944065093994, 0.08428119122982025, 0.08682900667190552, 0.08657509088516235, 0.08585011959075928, 0.0842280387878418, 0.08691074699163437, 0.08331817388534546, 0.08612687140703201, 0.08371055126190186, 0.08450517058372498, 0.08592954277992249, 0.08644121885299683, 0.08278194069862366, 0.08469808101654053, 0.08544813841581345, 0.086103655397892, 0.08436169475317001, 0.08417236059904099, 0.08710958808660507, 0.08373433351516724, 0.0860029011964798, 0.08613301813602448, 0.08432716131210327, 0.08500203490257263, 0.08370236307382584, 0.08383408933877945, 0.08405323326587677, 0.08223901689052582, 0.08373616635799408, 0.08470819890499115, 0.0856933742761612, 0.0834340825676918, 0.08595390617847443, 0.0847582295536995, 0.08393853902816772, 0.08546239137649536, 0.08634492754936218, 0.08511683344841003, 0.08577661961317062, 0.08420927822589874, 0.08475138247013092, 0.0837315022945404, 0.08334697782993317, 0.08628153055906296, 0.08427631855010986, 0.08519947528839111, 0.08381891250610352, 0.08487129211425781, 0.08422507345676422, 0.08414149284362793, 0.08403076231479645, 0.0849357545375824, 0.08383047580718994, 0.0854828879237175, 0.0834706574678421, 0.08547151833772659, 0.08313015103340149, 0.0879230946302414, 0.08524788916110992, 0.08484122902154922, 0.08502491563558578, 0.08379627764225006, 0.08479264378547668, ...
#   mejor_val: 0.08180353045463562
#   epocas_sin_mejora: 120
#
# [checkpoints_topnet/pretrain]
#   epoca: 124
#   historial_train: [0.28615045845508574, 0.25533160418272016, 0.23165942132472991, 0.2124958410859108, 0.19640830159187317, 0.16817818731069564, 0.16095563918352127, 0.1425096496939659, 0.138016913831234, 0.13473282307386397, 0.12912576794624328, 0.12443544641137123, 0.12177225723862647, 0.12039654180407525, 0.11518213599920273, 0.11606688946485519, 0.11264283657073974, 0.11443659737706184, 0.11608091071248054, 0.11037195026874543, 0.10734088197350503, 0.10628312453627586, 0.1034254215657711, 0.10446195006370544, 0.10281851291656494, 0.10342186018824577, 0.10269187167286872, 0.1042447492480278, 0.1030393309891224, 0.10055907741189003, 0.1004213623702526, 0.10058850273489953, 0.09901317954063416, 0.10143141597509384, 0.09965394139289856, 0.09834479466080666, 0.09747921004891395, 0.09779305830597877, 0.09820472747087479, 0.09930784851312638, 0.09589695483446121, 0.09566959366202354, 0.0955634742975235, 0.09489483609795571, 0.09607386440038682, 0.09543856307864189, 0.09441283717751503, 0.09423446282744408, 0.09469995275139809, 0.0950711764395237, 0.09329725652933121, 0.09403260424733162, 0.09460809007287026, 0.09449922367930412, 0.09339685067534446, 0.0939261220395565, 0.09416995942592621, 0.09327932670712472, 0.09408686235547066, 0.09345392808318138, 0.09391786009073258, 0.09381489008665085, 0.09212045967578888, 0.09205339848995209, 0.09081773087382317, 0.091346725076437, 0.09187571853399276, 0.09214852154254913, 0.09258324429392814, 0.09154573455452919, 0.09195777401328087, 0.09119779169559479, 0.09142773747444152, 0.09100179225206376, 0.09055311605334282, 0.09158478751778602, 0.09243810400366784, 0.09007602334022521, 0.0912400759756565, 0.09165664836764335, 0.09039161503314971, 0.09137375205755234, 0.09010667577385903, 0.09029599651694298, 0.09047654718160629, 0.09078942015767097, 0.08953731879591942, 0.09061696380376816, 0.08929817229509354, 0.09032552167773247, 0.08939613178372383, 0.08945766985416412, 0.09010352417826653, 0.09037116840481758, 0.09035868495702744, 0.08945040851831436, 0.08963867872953415, 0.09037813916802406, 0.08940890207886695, 0.09003816545009613, 0.09024750664830208, 0.08924149572849274, 0.08888878598809243, 0.08971910104155541, 0.0887107364833355, 0.08846682235598564, 0.08964117616415024, 0.0897308886051178, 0.08874141350388527, 0.0899970181286335, 0.0901314802467823, 0.0888400949537754, 0.08937240168452262, 0.08963478207588196, 0.08991201594471931, 0.09010462388396263, 0.08927249759435654, 0.08977992907166481, 0.08989248275756836, 0.08830388113856316, 0.08890185728669167, 0.08914416134357453, 0.08845384195446968, 0.08898716792464256]
#   historial_val: [0.2573375105857849, 0.24503090232610703, 0.2233562022447586, 0.2018502801656723, 0.16526170074939728, 0.16023355722427368, 0.13655437529087067, 0.12757661193609238, 0.1236281469464302, 0.1298794001340866, 0.1198248416185379, 0.11694415658712387, 0.11533180996775627, 0.10881530120968819, 0.10927170887589455, 0.11188450828194618, 0.1035735048353672, 0.11094794049859047, 0.10218656063079834, 0.1088939756155014, 0.09816735610365868, 0.09585895016789436, 0.0955081470310688, 0.09724432229995728, 0.0940745659172535, 0.09680918976664543, 0.0956592783331871, 0.09342056140303612, 0.09254827722907066, 0.08980254828929901, 0.09112077578902245, 0.09164374694228172, 0.09144166857004166, 0.09027133136987686, 0.08927623555064201, 0.08788558468222618, 0.09114198014140129, 0.08761391788721085, 0.08798312395811081, 0.08903098851442337, 0.08768728375434875, 0.0869254469871521, 0.0861385203897953, 0.08609528094530106, 0.08487096801400185, 0.08569392561912537, 0.08571286872029305, 0.08550750091671944, 0.08532905578613281, 0.08488471806049347, 0.08530744910240173, 0.08443522453308105, 0.08382872119545937, 0.0837891735136509, 0.0855635441839695, 0.08405894041061401, 0.08499108999967575, 0.08383089303970337, 0.0844881534576416, 0.0873110480606556, 0.08514460176229477, 0.08331671357154846, 0.08337187394499779, 0.08263976871967316, 0.08238617330789566, 0.08374851942062378, 0.0843936838209629, 0.08276307955384254, 0.08416019380092621, 0.08306543156504631, 0.08396332710981369, 0.08275432884693146, 0.08261589705944061, 0.08200100809335709, 0.08244336396455765, 0.0827261358499527, 0.08348824456334114, 0.083628099411726, 0.08325735107064247, 0.08319070562720299, 0.08284957334399223, 0.08216758817434311, 0.08196030929684639, 0.08139166980981827, 0.0820833295583725, 0.08187482878565788, 0.08119357377290726, 0.08099128305912018, 0.08128344267606735, 0.08203203231096268, 0.08161221817135811, 0.08195898681879044, 0.08237939700484276, 0.08233340084552765, 0.08186977729201317, 0.08203719183802605, 0.08175432309508324, 0.08172081410884857, 0.08161872997879982, 0.08166871964931488, 0.08164239302277565, 0.08132576197385788, 0.0804692730307579, 0.08098798617720604, 0.08076680079102516, 0.08092526346445084, 0.08125413209199905, 0.0809735618531704, 0.08115832135081291, 0.08088137209415436, 0.08075763285160065, 0.08105185255408287, 0.08136244490742683, 0.08089404925704002, 0.0811031311750412, 0.08142785355448723, 0.08167744800448418, 0.08155737072229385, 0.08106397837400436, 0.08086564764380455, 0.08107201755046844, 0.08103322610259056, 0.08098362758755684, 0.08084475621581078]
#   mejor_val: 0.0804692730307579
#   epocas_sin_mejora: 21
