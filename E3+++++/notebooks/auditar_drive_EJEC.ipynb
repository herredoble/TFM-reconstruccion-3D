# %% [markdown]
# # Auditoría de Drive — E3
#
# Ejecuta todas las celdas. Al final obtienes un bloque de texto que puedes copiar y pegar a Claude.
#
# No borra ni modifica nada — solo lista.

# %%
from google.colab import drive
import os
if os.path.isdir('/content/drive') and os.listdir('/content/drive'):
    print('Drive ya montado.')
else:
    drive.mount('/content/drive')
    print('Drive montado.')
# Out:
# Mounted at /content/drive
# Drive montado.

# %%
import os
from pathlib import Path
from datetime import datetime

DRIVE = '/content/drive/MyDrive'

# ── Rutas a escanear ─────────────────────────────────────────
# Añade aquí cualquier ruta adicional que quieras revisar
RUTAS = [
    # Datos de entrenamiento
    f'{DRIVE}/Datos_E2_E3/General',
    f'{DRIVE}/Datos_E2_E3/E3',
    f'{DRIVE}/Datos_E2_E3',
    # Nombres alternativos que se han usado en distintos momentos
    f'{DRIVE}/Datos_E3',
    f'{DRIVE}/TFM',
    f'{DRIVE}/TFM_datos',
    f'{DRIVE}/shapenet_limpias',
    f'{DRIVE}/objaverse_limpias',
    f'{DRIVE}/fantastic_breaks_procesado',
]

def tamanyo_legible(n_bytes):
    for u in ['B','KB','MB','GB']:
        if n_bytes < 1024: return f'{n_bytes:.1f} {u}'
        n_bytes /= 1024
    return f'{n_bytes:.1f} TB'

def escanear_carpeta(ruta, max_depth=3, _depth=0):
    """Devuelve lista de líneas descriptivas."""
    p = Path(ruta)
    lineas = []
    if not p.exists():
        return [f'  [NO EXISTE] {ruta}']
    try:
        hijos = sorted(p.iterdir())
    except PermissionError:
        return [f'  [SIN PERMISO] {ruta}']

    archivos = [h for h in hijos if h.is_file()]
    carpetas = [h for h in hijos if h.is_dir()]

    # Resumen de archivos en este nivel
    if archivos:
        por_ext = {}
        total_bytes = 0
        for f in archivos:
            try: sz = f.stat().st_size
            except: sz = 0
            total_bytes += sz
            ext = f.suffix.lower() or '(sin ext)'
            por_ext[ext] = por_ext.get(ext, 0) + 1
        ext_str = ', '.join(f'{v}x{k}' for k,v in sorted(por_ext.items()))
        ind = '  ' * (_depth + 1)
        lineas.append(f'{ind}📄 {len(archivos)} archivos [{ext_str}] — {tamanyo_legible(total_bytes)}')

    # Subcarpetas
    for c in carpetas:
        ind = '  ' * (_depth + 1)
        try:
            n_hijos = len(list(c.iterdir()))
        except: n_hijos = '?'
        # Tamaño de archivos directos
        try:
            arch_dir = [f for f in c.iterdir() if f.is_file()]
            sz_dir = sum(f.stat().st_size for f in arch_dir)
            sz_str = tamanyo_legible(sz_dir) if arch_dir else ''
        except: sz_str = ''

        lineas.append(f'{ind}📁 {c.name}/  ({n_hijos} elementos{(", "+sz_str) if sz_str else ""})')
        if _depth < max_depth - 1:
            lineas.extend(escanear_carpeta(c, max_depth, _depth + 1))

    return lineas


# ── Escaneo ───────────────────────────────────────────────────
bloques = []
vistas = set()

for ruta in RUTAS:
    p = Path(ruta)
    # Evitar escanear una carpeta padre si ya escaneamos una hija
    if not p.exists():
        bloques.append(f'\n[NO EXISTE] {ruta}')
        continue
    # Resolver ruta real
    try: real = str(p.resolve())
    except: real = ruta
    if real in vistas:
        bloques.append(f'\n[YA VISTO] {ruta} → {real}')
        continue
    vistas.add(real)

    bloques.append(f'\n{"="*60}')
    bloques.append(f'📂 {ruta}')
    bloques.append('='*60)
    bloques.extend(escanear_carpeta(ruta, max_depth=3))

for b in bloques:
    print(b)
# Out:
# ============================================================
# 📂 /content/drive/MyDrive/Datos_E2_E3/General
# ============================================================
#   📄 3 archivos [1x.csv, 1x.png, 1x.txt] — 401.0 KB
#   📁 Fantastik_Break_Preprocesado/  (123 elementos, 2.9 MB)
#     📄 122 archivos [122x.npy] — 2.9 MB
#     📁 Fantastik_Break_Preprocesado/  (123 elementos, 2.9 MB)
#       📄 122 archivos [122x.npy] — 2.9 MB
#       📁 Fantastik_Break_Preprocesado/  (123 elementos, 2.9 MB)
#   📁 Fantastik_Break_Procesado_v2/  (120 elementos, 2.8 MB)
#     📄 120 archivos [120x.npy] — 2.8 MB
#   📁 Objaverse_limpias/  (197 elementos, 214.1 MB)
#     📄 197 archivos [197x.ply] — 214.1 MB
#   📁 Objaverse_limpias_v2/  (131 elementos, 317.8 MB)
#     📄 131 archivos [131x.ply] — 317.8 MB
#   📁 Shapenet_limpias/  (7 elementos)
#     📁 02747177/  (277 elementos, 164.1 MB)
#       📄 277 archivos [277x.ply] — 164.1 MB
#     📁 02876657/  (453 elementos, 122.6 MB)
#       📄 453 archivos [453x.ply] — 122.6 MB
#     📁 02880940/  (146 elementos, 33.2 MB)
#       📄 146 archivos [146x.ply] — 33.2 MB
#     📁 02946921/  (88 elementos, 24.1 MB)
#       📄 88 archivos [88x.ply] — 24.1 MB
#     📁 03593526/  (545 elementos, 309.2 MB)
#       📄 545 archivos [545x.ply] — 309.2 MB
#     📁 03797390/  (172 elementos, 43.0 MB)
#       📄 172 archivos [172x.ply] — 43.0 MB
#     📁 03991062/  (489 elementos, 405.4 MB)
#       📄 489 archivos [489x.ply] — 405.4 MB
#   📁 Shapenet_procesado/  (1 elementos, 186.2 MB)
#     📄 1 archivos [1x.zip] — 186.2 MB
#   📁 Shapenet_raw/  (7 elementos, 670.9 MB)
#     📄 7 archivos [7x.zip] — 670.9 MB
#   📁 roturas_Objaverse_v2/  (794 elementos, 18.7 MB)
#     📄 794 archivos [794x.npy] — 18.7 MB
#   📁 shapenet_roturas/  (4208 elementos, 99.1 MB)
#     📄 4208 archivos [4208x.npy] — 99.1 MB
#   📁 sintetico_roturas/  (395 elementos, 9.3 MB)
#     📄 394 archivos [394x.npy] — 9.3 MB
#     📁 sintetico_roturas/  (395 elementos, 9.3 MB)
#       📄 394 archivos [394x.npy] — 9.3 MB
#       📁 sintetico_roturas/  (395 elementos, 9.3 MB)
#
# ============================================================
# 📂 /content/drive/MyDrive/Datos_E2_E3/E3
# ============================================================
#   📁 Raquel/  (5 elementos, 800.0 B)
#     📄 1 archivos [1x.csv] — 800.0 B
#     📁 modelos/  (12 elementos)
#       📁 v1_pcn/  (1 elementos, 59.1 MB)
#       📁 v1_pointr/  (1 elementos, 397.7 MB)
#       📁 v2_pcn/  (0 elementos)
#       📁 v2_pointr/  (1 elementos, 397.7 MB)
#       📁 v3_pcn/  (1 elementos, 59.1 MB)
#       📁 v3_pointr/  (12 elementos, 4.7 GB)
#       📁 v4_pcn/  (1 elementos, 59.1 MB)
#       📁 v4_pointr_fbv2/  (31 elementos, 12.0 GB)
#       📁 v5_fb_obj/  (31 elementos, 12.0 GB)
#       📁 v5_obj/  (31 elementos, 12.0 GB)
#       📁 v5_pcn/  (1 elementos, 59.1 MB)
#       📁 v5_pointr_objaverse_fbv2/  (2 elementos)
#     📁 notebooks/  (19 elementos, 20.9 MB)
#       📄 19 archivos [19x.ipynb] — 20.9 MB
#     📁 resultados/  (11 elementos)
#       📁 v1_pcn/  (10 elementos, 910.4 KB)
#       📁 v1_pointr/  (1 elementos, 86.0 B)
#       📁 v2_pointr/  (1 elementos, 86.0 B)
#       📁 v3_pcn/  (16 elementos, 1.9 MB)
#       📁 v3_pointr/  (0 elementos)
#       📁 v4_pcn/  (18 elementos, 2.2 MB)
#       📁 v4_pointr_fbv2/  (1 elementos, 107.0 B)
#       📁 v5_fb_obj/  (2 elementos, 421.0 B)
#       📁 v5_obj/  (2 elementos, 398.0 B)
#       📁 v5_pcn/  (18 elementos, 2.2 MB)
#       📁 v5_pointr_objaverse_fbv2/  (1 elementos, 115.0 B)
#     📁 visualizaciones/  (1 elementos)
#       📁 v5_fb_obj/  (9 elementos, 2.0 MB)
#   📁 checkpoints_pcn/  (56 elementos, 879.3 MB)
#     📄 56 archivos [56x.pt] — 879.3 MB
#   📁 checkpoints_pcn_v3/  (15 elementos, 251.2 MB)
#     📄 15 archivos [1x.json, 14x.pt] — 251.2 MB
#   📁 checkpoints_pcn_v4/  (1 elementos)
#     📁 pretrain/  (9 elementos, 157.0 MB)
#       📄 9 archivos [1x.json, 8x.pt] — 157.0 MB
#   📁 checkpoints_pcn_v8/  (1 elementos)
#     📁 finetune/  (8 elementos, 141.3 MB)
#       📄 8 archivos [1x.json, 7x.pt] — 141.3 MB
#   📁 checkpoints_pcn_v9/  (2 elementos)
#     📁 finetune/  (25 elementos, 408.2 MB)
#       📄 25 archivos [1x.json, 24x.pt] — 408.2 MB
#     📁 pretrain/  (9 elementos, 157.0 MB)
#       📄 9 archivos [1x.json, 8x.pt] — 157.0 MB
#   📁 checkpoints_topnet/  (3 elementos)
#     📁 finetune/  (17 elementos, 97.0 MB)
#       📄 17 archivos [1x.json, 16x.pt] — 97.0 MB
#     📁 finetune_congelado/  (19 elementos, 99.2 MB)
#       📄 19 archivos [1x.json, 18x.pt] — 99.2 MB
#     📁 pretrain/  (7 elementos, 43.1 MB)
#       📄 7 archivos [1x.json, 6x.pt] — 43.1 MB
#
# ============================================================
# 📂 /content/drive/MyDrive/Datos_E2_E3
# ============================================================
#   📁 (borrar?) PCN-PyTorch/  (16 elementos, 17.8 KB)
#     📄 5 archivos [1x(sin ext), 1x.md, 2x.py, 1x.txt] — 17.8 KB
#     📁 .git/  (11 elementos, 6.0 KB)
#       📄 5 archivos [5x(sin ext)] — 6.0 KB
#       📁 branches/  (0 elementos)
#       📁 hooks/  (13 elementos, 22.9 KB)
#       📁 info/  (1 elementos, 240.0 B)
#       📁 logs/  (2 elementos, 186.0 B)
#       📁 objects/  (2 elementos)
#       📁 refs/  (3 elementos)
#     📁 checkpoint/  (1 elementos, 26.2 MB)
#       📄 1 archivos [1x.pth] — 26.2 MB
#     📁 data/  (1 elementos, 91.0 B)
#       📄 1 archivos [1x.md] — 91.0 B
#     📁 dataset/  (2 elementos, 3.6 KB)
#       📄 2 archivos [2x.py] — 3.6 KB
#     📁 extensions/  (2 elementos)
#       📁 chamfer_distance/  (6 elementos, 9.7 KB)
#       📁 earth_movers_distance/  (5 elementos, 13.9 KB)
#     📁 images/  (13 elementos, 3.8 MB)
#       📄 13 archivos [13x.png] — 3.8 MB
#     📁 metrics/  (2 elementos, 2.3 KB)
#       📄 2 archivos [2x.py] — 2.3 KB
#     📁 models/  (3 elementos, 3.6 KB)
#       📄 2 archivos [2x.py] — 3.6 KB
#       📁 __pycache__/  (2 elementos, 5.8 KB)
#     📁 render/  (6 elementos, 36.6 KB)
#       📄 6 archivos [1x.log, 1x.md, 1x.png, 2x.py, 1x.sh] — 36.6 KB
#     📁 sample/  (4 elementos, 1.2 MB)
#       📄 4 archivos [1x(sin ext), 1x.cpp, 1x.md, 1x.txt] — 1.2 MB
#     📁 visualization/  (2 elementos, 1.3 KB)
#       📄 2 archivos [2x.py] — 1.3 KB
#   📁 E2/  (4 elementos)
#     📁 Datos_E2_voxel/  (9 elementos, 979.1 KB)
#       📄 2 archivos [2x.csv] — 979.1 KB
#       📁 02747177/  (277 elementos)
#       📁 02876657/  (453 elementos)
#       📁 02880940/  (146 elementos)
#       📁 02946921/  (88 elementos)
#       📁 03593526/  (545 elementos)
#       📁 03797390/  (172 elementos)
#       📁 03991062/  (489 elementos)
#     📁 Fantastik_Break_Pix2Vox/  (13 elementos, 627.0 B)
#       📄 1 archivos [1x.json] — 627.0 B
#       📁 comparacion_bpa/  (3 elementos)
#       📁 gt_roto_voxel_32/  (61 elementos, 1.9 MB)
#       📁 informes/  (4 elementos, 132.9 KB)
#       📁 mallas_bpa/  (61 elementos, 11.1 MB)
#       📁 predicciones_pix2vox_malla/  (61 elementos, 6.7 MB)
#       📁 predicciones_pix2vox_pointcloud/  (61 elementos, 1.4 MB)
#       📁 predicciones_pix2vox_voxel/  (122 elementos, 9.5 MB)
#       📁 pruebas_template_completa/  (4 elementos)
#       📁 pruebas_template_v2/  (5 elementos, 128.0 B)
#       📁 pruebas_template_v3/  (4 elementos, 128.0 B)
#       📁 puntos_render/  (61 elementos, 1.4 MB)
#       📁 renders_5v/  (61 elementos)
#     📁 Img E2/  (28 elementos, 1.3 MB)
#       📄 21 archivos [19x.csv, 1x.json, 1x.xlsx] — 1.3 MB
#       📁 02747177/  (277 elementos)
#       📁 02876657/  (453 elementos)
#       📁 02880940/  (146 elementos)
#       📁 02946921/  (88 elementos)
#       📁 03593526/  (545 elementos)
#       📁 03797390/  (172 elementos)
#       📁 03991062/  (489 elementos)
#     📁 Pix2Vox++/  (9 elementos)
#       📁 catalogos/  (7 elementos, 14.1 MB)
#       📁 checkpoints/  (10 elementos, 3.6 GB)
#       📁 divisiones/  (20 elementos, 15.5 MB)
#       📁 historiales/  (20 elementos, 82.6 KB)
#       📁 logs/  (0 elementos)
#       📁 metricas/  (21 elementos)
#       📁 pesos_preentrenados/  (1 elementos, 367.6 MB)
#       📁 predicciones_binvox/  (0 elementos)
#       📁 tablas_resultados/  (14 elementos, 10.6 KB)
#   📁 E3/  (7 elementos)
#     📁 Raquel/  (5 elementos, 800.0 B)
#       📄 1 archivos [1x.csv] — 800.0 B
#       📁 modelos/  (12 elementos)
#       📁 notebooks/  (19 elementos, 20.9 MB)
#       📁 resultados/  (11 elementos)
#       📁 visualizaciones/  (1 elementos)
#     📁 checkpoints_pcn/  (56 elementos, 879.3 MB)
#       📄 56 archivos [56x.pt] — 879.3 MB
#     📁 checkpoints_pcn_v3/  (15 elementos, 251.2 MB)
#       📄 15 archivos [1x.json, 14x.pt] — 251.2 MB
#     📁 checkpoints_pcn_v4/  (1 elementos)
#       📁 pretrain/  (9 elementos, 157.0 MB)
#     📁 checkpoints_pcn_v8/  (1 elementos)
#       📁 finetune/  (8 elementos, 141.3 MB)
#     📁 checkpoints_pcn_v9/  (2 elementos)
#       📁 finetune/  (25 elementos, 408.2 MB)
#       📁 pretrain/  (9 elementos, 157.0 MB)
#     📁 checkpoints_topnet/  (3 elementos)
#       📁 finetune/  (17 elementos, 97.0 MB)
#       📁 finetune_congelado/  (19 elementos, 99.2 MB)
#       📁 pretrain/  (7 elementos, 43.1 MB)
#   📁 General/  (13 elementos, 401.0 KB)
#     📄 3 archivos [1x.csv, 1x.png, 1x.txt] — 401.0 KB
#     📁 Fantastik_Break_Preprocesado/  (123 elementos, 2.9 MB)
#       📄 122 archivos [122x.npy] — 2.9 MB
#       📁 Fantastik_Break_Preprocesado/  (123 elementos, 2.9 MB)
#     📁 Fantastik_Break_Procesado_v2/  (120 elementos, 2.8 MB)
#       📄 120 archivos [120x.npy] — 2.8 MB
#     📁 Objaverse_limpias/  (197 elementos, 214.1 MB)
#       📄 197 archivos [197x.ply] — 214.1 MB
#     📁 Objaverse_limpias_v2/  (131 elementos, 317.8 MB)
#       📄 131 archivos [131x.ply] — 317.8 MB
#     📁 Shapenet_limpias/  (7 elementos)
#       📁 02747177/  (277 elementos, 164.1 MB)
#       📁 02876657/  (453 elementos, 122.6 MB)
#       📁 02880940/  (146 elementos, 33.2 MB)
#       📁 02946921/  (88 elementos, 24.1 MB)
#       📁 03593526/  (545 elementos, 309.2 MB)
#       📁 03797390/  (172 elementos, 43.0 MB)
#       📁 03991062/  (489 elementos, 405.4 MB)
#     📁 Shapenet_procesado/  (1 elementos, 186.2 MB)
#       📄 1 archivos [1x.zip] — 186.2 MB
#     📁 Shapenet_raw/  (7 elementos, 670.9 MB)
#       📄 7 archivos [7x.zip] — 670.9 MB
#     📁 roturas_Objaverse_v2/  (794 elementos, 18.7 MB)
#       📄 794 archivos [794x.npy] — 18.7 MB
#     📁 shapenet_roturas/  (4208 elementos, 99.1 MB)
#       📄 4208 archivos [4208x.npy] — 99.1 MB
#     📁 sintetico_roturas/  (395 elementos, 9.3 MB)
#       📄 394 archivos [394x.npy] — 9.3 MB
#       📁 sintetico_roturas/  (395 elementos, 9.3 MB)
#   📁 Pix2Vox++/  (9 elementos)
#     📁 catalogos/  (2 elementos, 441.0 KB)
#       📄 2 archivos [2x.csv] — 441.0 KB
#     📁 checkpoints/  (0 elementos)
#     📁 divisiones/  (4 elementos, 443.1 KB)
#       📄 4 archivos [3x.csv, 1x.json] — 443.1 KB
#     📁 historiales/  (0 elementos)
#     📁 logs/  (0 elementos)
#     📁 metricas/  (0 elementos)
#     📁 pesos_preentrenados/  (0 elementos)
#     📁 predicciones_binvox/  (0 elementos)
#     📁 tablas_resultados/  (0 elementos)
#
# [NO EXISTE] /content/drive/MyDrive/Datos_E3
#
# [NO EXISTE] /content/drive/MyDrive/TFM
#
# [NO EXISTE] /content/drive/MyDrive/TFM_datos
#
# [NO EXISTE] /content/drive/MyDrive/shapenet_limpias
#
# [NO EXISTE] /content/drive/MyDrive/objaverse_limpias
#
# [NO EXISTE] /content/drive/MyDrive/fantastic_breaks_procesado

# %%
# ── Detalle de carpetas de modelos y resultados ───────────────
# Lista los checkpoints guardados por experimento con su tamaño y fecha

from pathlib import Path
from datetime import datetime
import os

DRIVE = '/content/drive/MyDrive'
BASE_E3 = f'{DRIVE}/Datos_E2_E3/E3/Raquel'

def fecha_mod(p):
    try: return datetime.fromtimestamp(p.stat().st_mtime).strftime('%Y-%m-%d %H:%M')
    except: return '?'

def tamanyo_legible(n):
    for u in ['B','KB','MB','GB']:
        if n < 1024: return f'{n:.0f} {u}'
        n /= 1024
    return f'{n:.1f} TB'

print('=' * 70)
print('CHECKPOINTS DE MODELOS')
print('=' * 70)

modelos_dir = Path(f'{BASE_E3}/modelos')
if modelos_dir.exists():
    for exp in sorted(modelos_dir.iterdir()):
        if not exp.is_dir(): continue
        ckpts = sorted(exp.glob('*.pt'))
        total = sum(f.stat().st_size for f in ckpts if f.exists())
        print(f'\n  📁 {exp.name}/  ({tamanyo_legible(total)} total)')
        for c in ckpts:
            try: sz = tamanyo_legible(c.stat().st_size)
            except: sz = '?'
            print(f'    {c.name:25s}  {sz:>8}  {fecha_mod(c)}')
else:
    print(f'  [NO EXISTE] {modelos_dir}')

print()
print('=' * 70)
print('RESULTADOS (metricas.json)')
print('=' * 70)

import json
resultados_dir = Path(f'{BASE_E3}/resultados')
if resultados_dir.exists():
    for exp in sorted(resultados_dir.iterdir()):
        if not exp.is_dir(): continue
        m_path = exp / 'metricas.json'
        archivos = list(exp.iterdir())
        if m_path.exists():
            try:
                m = json.loads(m_path.read_text())
                print(f'\n  📁 {exp.name}/')
                print(f'    version={m.get("version")}  modelo={m.get("modelo")}')
                print(f'    datasets={m.get("datasets")}  pares={m.get("n_pares_total")}  test={m.get("n_test")}')
                print(f'    epochs={m.get("epochs")}  best_epoch={m.get("best_epoch")}')
                print(f'    CD-L1={m.get("cd_l1")}  F-Score={m.get("f_score")}')
                print(f'    notas={m.get("notas")}')
                otros = [f.name for f in archivos if f.name != 'metricas.json']
                if otros: print(f'    otros: {otros}')
            except Exception as e:
                print(f'  📁 {exp.name}/  [ERROR leyendo metricas.json: {e}]')
        else:
            print(f'\n  📁 {exp.name}/  (sin metricas.json — archivos: {[f.name for f in archivos]})')
else:
    print(f'  [NO EXISTE] {resultados_dir}')
# Out:
# ======================================================================
# CHECKPOINTS DE MODELOS
# ======================================================================
#
#   📁 v1_pcn/  (59 MB total)
#     best.pt                       59 MB  2026-08-05 12:04
#
#   📁 v1_pointr/  (398 MB total)
#     best.pt                      398 MB  2026-08-20 07:55
#
#   📁 v2_pcn/  (0 B total)
#
#   📁 v2_pointr/  (398 MB total)
#     best.pt                      398 MB  2026-08-24 11:06
#
#   📁 v3_pcn/  (59 MB total)
#     best.pt                       59 MB  2026-08-13 17:41
#
#   📁 v3_pointr/  (5 GB total)
#     best.pt                      398 MB  2026-08-24 16:22
#     epoch_010.pt                 398 MB  2026-08-24 16:08
#     epoch_020.pt                 398 MB  2026-08-24 16:10
#     epoch_030.pt                 398 MB  2026-08-24 16:13
#     epoch_040.pt                 398 MB  2026-08-24 16:14
#     epoch_050.pt                 398 MB  2026-08-24 16:16
#     epoch_060.pt                 398 MB  2026-08-24 16:18
#     epoch_070.pt                 398 MB  2026-08-24 16:20
#     epoch_080.pt                 398 MB  2026-08-24 16:22
#     epoch_090.pt                 398 MB  2026-08-24 16:23
#     epoch_100.pt                 398 MB  2026-08-24 16:25
#     epoch_110.pt                 398 MB  2026-08-24 16:26
#
#   📁 v4_pcn/  (59 MB total)
#     best.pt                       59 MB  2026-08-15 17:01
#
#   📁 v4_pointr_fbv2/  (12 GB total)
#     best.pt                      398 MB  2026-08-25 10:22
#     epoch_010.pt                 398 MB  2026-08-25 10:04
#     epoch_020.pt                 398 MB  2026-08-25 10:05
#     epoch_030.pt                 398 MB  2026-08-25 10:06
#     epoch_040.pt                 398 MB  2026-08-25 10:07
#     epoch_050.pt                 398 MB  2026-08-25 10:08
#     epoch_060.pt                 398 MB  2026-08-25 10:09
#
#   📁 v3_pointr/  (sin metricas.json — archivos: [])
#
#   📁 v4_pcn/  (sin metricas.json — archivos: ['figura_004_mejor_184.png', 'figura_003_mejor_33.png', 'figura_006_peor_150.png', 'figura_008_peor_124.png', 'figura_002_mejor_57.png', 'figura_005_peor_172.png', 'figura_001_mejor_37.png', 'figura_007_peor_63.png', 'resumen.txt', 'metricas.csv', 'figura_001_mejor_39.png', 'figura_002_mejor_210.png', 'figura_003_mejor_181.png', 'figura_004_mejor_155.png', 'figura_005_peor_81.png', 'figura_006_peor_134.png', 'figura_007_peor_117.png', 'figura_008_peor_22.png'])
#
#   📁 v4_pointr_fbv2/  (sin metricas.json — archivos: ['resumen.txt'])
#
#   📁 v5_fb_obj/
#     version=v5_fb_obj  modelo=PoinTr
#     datasets=['fb', 'obj']  pares=457  test=47
#     epochs=300  best_epoch=289
#     CD-L1=0.032336724882430216  F-Score=0.25484300951691385
#     notas=
#     otros: ['resumen.txt']
#
#   📁 v5_obj/
#     version=v5_obj  modelo=PoinTr
#     datasets=['obj']  pares=397  test=41
#     epochs=300  best_epoch=257
#     CD-L1=0.03061180161993678  F-Score=0.27010351255899523
#     notas=
#     otros: ['resumen.txt']
#
#   📁 v5_pcn/  (sin metricas.json — archivos: ['figura_001_mejor_37.png', 'figura_005_peor_172.png', 'figura_004_mejor_184.png', 'figura_007_peor_63.png', 'figura_002_mejor_57.png', 'figura_008_peor_124.png', 'figura_006_peor_150.png', 'figura_003_mejor_33.png', 'metricas.csv', 'resumen.txt', 'figura_001_mejor_39.png', 'figura_002_mejor_181.png', 'figura_004_mejor_26.png', 'figura_003_mejor_155.png', 'figura_005_peor_117.png', 'figura_006_peor_81.png', 'figura_008_peor_22.png', 'figura_007_peor_133.png'])
#
#   📁 v5_pointr_objaverse_fbv2/  (sin metricas.json — archivos: ['resumen.txt'])

# %%
# ── Resumen final para copiar a Claude ───────────────────────
# Copia TODO el output de esta celda y pégalo en el chat

from pathlib import Path
from datetime import datetime
import json

DRIVE = '/content/drive/MyDrive'
BASE_E3 = f'{DRIVE}/Datos_E2_E3/E3/Raquel'
BASE_GEN = f'{DRIVE}/Datos_E2_E3/General'

lineas = []
lineas.append('=== AUDITORÍA DRIVE ===')
lineas.append(f'Fecha: {datetime.now().strftime("%Y-%m-%d %H:%M")}')

def tamanyo(n):
    for u in ['B','KB','MB','GB']:
        if n < 1024: return f'{n:.0f}{u}'
        n /= 1024
    return f'{n:.1f}TB'

# --- Datasets en General ---
lineas.append('')
lineas.append('--- DATASETS (General/) ---')
gen = Path(BASE_GEN)
if gen.exists():
    for d in sorted(gen.iterdir()):
        if d.is_dir():
            try:
                archivos = list(d.iterdir())
                npys = [f for f in archivos if f.suffix == '.npy']
                plys = [f for f in archivos if f.suffix == '.ply']
                otros_ext = set(f.suffix for f in archivos if f.suffix not in ('.npy','.ply'))
                sz = sum(f.stat().st_size for f in archivos if f.is_file())
                det = f'{len(npys)}x.npy' if npys else ''
                det += f' {len(plys)}x.ply' if plys else ''
                det += f' otros:{otros_ext}' if otros_ext else ''
                lineas.append(f'  {d.name}/  {tamanyo(sz)}  [{det.strip()}]')
            except Exception as e:
                lineas.append(f'  {d.name}/  [ERROR: {e}]')
        else:
            lineas.append(f'  {d.name}  (archivo)')
else:
    lineas.append(f'  [NO EXISTE] {BASE_GEN}')

# --- Modelos ---
lineas.append('')
lineas.append('--- MODELOS (E3/Raquel/modelos/) ---')
mod = Path(f'{BASE_E3}/modelos')
if mod.exists():
    for exp in sorted(mod.iterdir()):
        if exp.is_dir():
            ckpts = sorted(exp.glob('*.pt'))
            names = [c.name for c in ckpts]
            sz = sum(c.stat().st_size for c in ckpts if c.exists())
            lineas.append(f'  {exp.name}/  {tamanyo(sz)}  {names}')
else:
    lineas.append(f'  [NO EXISTE] {mod}')

# --- Resultados ---
lineas.append('')
lineas.append('--- RESULTADOS (E3/Raquel/resultados/) ---')
res = Path(f'{BASE_E3}/resultados')
if res.exists():
    for exp in sorted(res.iterdir()):
        if exp.is_dir():
            m_path = exp / 'metricas.json'
            if m_path.exists():
                try:
                    m = json.loads(m_path.read_text())
                    lineas.append(f'  {exp.name}/  CD={m.get("cd_l1")}  F={m.get("f_score")}'
                                  f'  ep={m.get("best_epoch")}  test={m.get("n_test")}')
                except:
                    lineas.append(f'  {exp.name}/  [metricas.json ilegible]')
            else:
                archs = [f.name for f in exp.iterdir()]
                lineas.append(f'  {exp.name}/  [sin metricas.json]  archivos={archs}')
else:
    lineas.append(f'  [NO EXISTE] {res}')

# --- Resto de E3/Raquel ---
lineas.append('')
lineas.append('--- RESTO E3/Raquel/ ---')
e3r = Path(BASE_E3)
if e3r.exists():
    for d in sorted(e3r.iterdir()):
        if d.name in ('modelos','resultados'): continue
        if d.is_dir():
            try:
                n = len(list(d.iterdir()))
                lineas.append(f'  {d.name}/  ({n} elementos)')
            except:
                lineas.append(f'  {d.name}/  [error]')
        else:
            lineas.append(f'  {d.name}  (archivo)')
else:
    lineas.append(f'  [NO EXISTE] {BASE_E3}')

lineas.append('')
lineas.append('=== FIN AUDITORÍA ===')

print('\n'.join(lineas))
print()
print('↑ Copia todo el texto entre las líneas === y pégalo en Claude.')
# Out:
# === AUDITORÍA DRIVE ===
# Fecha: 2026-08-27 18:10
#
# --- DATASETS (General/) ---
#   Fantastik_Break_Preprocesado/  3MB  [122x.npy otros:{''}]
#   Fantastik_Break_Procesado_v2/  3MB  [120x.npy]
#   Objaverse_limpias/  214MB  [197x.ply]
#   Objaverse_limpias_v2/  318MB  [131x.ply]
#   Shapenet_limpias/  0B  [otros:{''}]
#   Shapenet_procesado/  186MB  [otros:{'.zip'}]
#   v5_pcn/  59MB  ['best.pt']
#   v5_pointr_objaverse_fbv2/  0B  []
#
# --- RESULTADOS (E3/Raquel/resultados/) ---
#   v1_pcn/  [sin metricas.json]  archivos=['resumen.txt', 'metricas.csv', 'figura_002_mejor_57.png', 'figura_001_mejor_37.png', 'figura_003_mejor_33.png', 'figura_005_peor_172.png', 'figura_004_mejor_184.png', 'figura_007_peor_63.png', 'figura_006_peor_150.png', 'figura_008_peor_124.png']
#   v1_pointr/  [sin metricas.json]  archivos=['resumen.txt']
#   v2_pointr/  [sin metricas.json]  archivos=['resumen.txt']
#   v3_pcn/  [sin metricas.json]  archivos=['figura_008_peor_124.png', 'figura_002_mejor_57.png', 'figura_007_peor_63.png', 'figura_004_mejor_184.png', 'figura_006_peor_150.png', 'figura_005_peor_172.png', 'metricas.csv', 'resumen.txt', 'figura_002_mejor_67.png', 'figura_001_mejor_37.png', 'figura_003_mejor_33.png', 'figura_004_mejor_203.png', 'figura_005_peor_97.png', 'figura_006_peor_188.png', 'figura_007_peor_60.png', 'figura_008_peor_193.png']
#   v3_pointr/  [sin metricas.json]  archivos=[]
#   v4_pcn/  [sin metricas.json]  archivos=['figura_004_mejor_184.png', 'figura_003_mejor_33.png', 'figura_006_peor_150.png', 'figura_008_peor_124.png', 'figura_002_mejor_57.png', 'figura_005_peor_172.png', 'figura_001_mejor_37.png', 'figura_007_peor_63.png', 'resumen.txt', 'metricas.csv', 'figura_001_mejor_39.png', 'figura_002_mejor_210.png', 'figura_003_mejor_181.png', 'figura_004_mejor_155.png', 'figura_005_peor_81.png', 'figura_006_peor_134.png', 'figura_007_peor_117.png', 'figura_008_peor_22.png']
#   v4_pointr_fbv2/  [sin metricas.json]  archivos=['resumen.txt']
#   v5_fb_obj/  CD=0.032336724882430216  F=0.25484300951691385  ep=289  test=47
#   v5_obj/  CD=0.03061180161993678  F=0.27010351255899523  ep=257  test=41
#   v5_pcn/  [sin metricas.json]  archivos=['figura_001_mejor_37.png', 'figura_005_peor_172.png', 'figura_004_mejor_184.png', 'figura_007_peor_63.png', 'figura_002_mejor_57.png', 'figura_008_peor_124.png', 'figura_006_peor_150.png', 'figura_003_mejor_33.png', 'metricas.csv', 'resumen.txt', 'figura_001_mejor_39.png', 'figura_002_mejor_181.png', 'figura_004_mejor_26.png', 'figura_003_mejor_155.png', 'figura_005_peor_117.png', 'figura_006_peor_81.png', 'figura_008_peor_22.png', 'figura_007_peor_133.png']
#   v5_pointr_objaverse_fbv2/  [sin metricas.json]  archivos=['resumen.txt']
#
# --- RESTO E3/Raquel/ ---
#   comparativa_experimentos.csv  (archivo)
#   notebooks/  (19 elementos)
#   visualizaciones/  (1 elementos)
#
# === FIN AUDITORÍA ===
#
# ↑ Copia todo el texto entre las líneas === y pégalo en Claude.
